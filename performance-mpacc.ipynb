# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web
from pyalgotrade.barfeed import csvfeed, yahoofeed
from pyalgotrade.bar import Frequency
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <div class="jumbotron">
#     <p class="display-1 h1">量化交易模型评估</p>
#     <hr class="my-4">
#     <p>主讲：李岩</p>
#     <p>管理学院</p>
#     <p>liyan@cumtb.edu.cn</p>
# </div>

# %% [markdown]
# <center><img src="./img/performance/performanceFramework.png" width=100%></center>

# %% [markdown]
# # 评估指标

# %% [markdown]
# ##### 总收益率

# %% [markdown]
# $$
#     \text{总收益率}=\frac{\text{期末权益}-\text{期初权益}}{\text{期初权益}}
# $$

# %% [markdown]
# ##### 当日收益率

# %% [markdown]
# $$
#     \text{当日收益率}=\frac{\text{当日权益}+\text{当日出金}}{\text{昨日权益}+\text{昨日入金}}-1
# $$

# %% [markdown]
# ##### 当日净值

# %% [markdown]
# $$
#     \text{当日净值}=1+\text{当日收益率}
# $$

# %% [markdown]
# ##### 累计净值

# %% [markdown]
# $$
#     P=\Pi_{i=1}^n P_i
# $$
#
# - $P_i$为第$i$天的当日净值

# %% [markdown]
# ##### 最大回撤

# %% [markdown]
# - 回撤：一个净值高点与下一个净值高点之间出现的最低点与高点之间的回落百分比

# %% [markdown]
# <center><img src="./img/performance/drawdown.png" width=100%></center>

# %% [markdown]
# $$
#     \text{历史最大回撤率}=\max\{\frac{\text{历史最大累计净值}-\text{当日累计净值}}{\text{历史最大累计净值}}\}
# $$

# %% [markdown]
# ##### 夏普比率

# %% [markdown]
# $$
#     \text{sharpe ratio}=\frac{E(r）-r_f}{\sigma}
# $$

# %% [markdown]
# - $r_f$：无风险收益率
# - $r$：投资组合的收益率
# - $\sigma$：投资组合收益的标准差

# %% [markdown]
# ##### 信息比率

# %% [markdown]
# $$
#     \text{information ratio} = \frac{E(r)-E(r_B)}{\sigma_{r-r_B}}
# $$

# %% [markdown]
# - $r_B$：基准投资组合收益率
# - $\sigma_{r-r_B}$：当前投资组合与基准投资组合收益率差的标准差

# %% [markdown]
# # 样本内绩效

# %% [markdown]
# ## 样本内数据

# %% [markdown]
# - 真实交易的历史数据

# %% [markdown]
# - 生成的模拟交易数据

# %% [markdown]
# - 基本面数据

# %% [markdown]
# ## 回测框架

# %% [markdown]
# <center><img src="./img/performance/backtestFramework.png" width=100%></center>

# %% [markdown]
# ### 事件驱动（event-driven）的回测框架

# %% [markdown]
# - 一个时间循环，依据市场当时的情况发出交易信号

# %% [markdown]
# - 优点
#     - 更加趋于真实交易的回测，代码经过简单修正可以用于实盘交易
#     - 灵活，可以回测复杂的交易逻辑
#     - 可以避免**前瞻性偏差（lookahead bias）**

# %% [markdown]
# - 缺点
#     - 代码量大
#     - 回测速度慢

# %% [markdown]
# ### 向量化（vectorized）回测框架

# %% [markdown]
# - 获取交易策略所需要的所有数据与指标，将其转换成向量，利用线性代数的方法回测

# %% [markdown]
# - 优势
#     - 代码量小
#     - 回测速度快

# %% [markdown]
# - 缺点
#     - 不灵活
#     - 易于出现前瞻性偏差

# %% [markdown]
# ### 当前主要的回测框架

# %% [markdown]
# ##### `PyAlgoTrade`

# %% [markdown]
# - 事件驱动的回测框架
# - 支持比特币的实盘交易
# - 集成`TA-Lib`
# - [http://gbeced.github.io/pyalgotrade/](http://gbeced.github.io/pyalgotrade/)

# %% [markdown]
# ##### `Zipline`

# %% [markdown]
# - 事件驱动的回测框架
# - Quantopian基于该框架开发了云计算支持的回测
# - 用户规模大
# - [https://www.zipline.io](https://www.zipline.io)

# %% [markdown]
# ##### `Backtrader`

# %% [markdown]
# - 事件驱动型和向量型回测框架
# - 支持实盘交易（国外）
# - [https://www.backtrader.com](https://www.backtrader.com)

# %% [markdown]
# ##### `backtesting.py`

# %% [markdown]
# - 事件驱动型回测框架
# - 交互式图表
# - [https://github.com/kernc/backtesting.py](https://github.com/kernc/backtesting.py)

# %% [markdown]
# ##### `Vn.py`

# %% [markdown]
# - 事件驱动型回测框架
# - 支持`CTP`实盘交易
# - 国内开发的回测框架
# - [https://www.vnpy.com](https://www.vnpy.com)

# %% [markdown]
# ## `PyAlgoTrade`

# %% [markdown]
# - 中文文档 [https://pyalgotrade-docs-zh-cn.readthedocs.io/zh_CN/latest/tutorial.html](https://pyalgotrade-docs-zh-cn.readthedocs.io/zh_CN/latest/tutorial.html)

# %% [markdown]
# - 特点
#     - 事件驱动型
#     - 支持**市价(market)**、**限价(limit)**、**止损(stop)**等交易指令
#     - 支持`csv`格式存储的时间序列数据
#     - 集成`TA-Lib`
#     - 支持`Bitcoin`交易
#     - 支持实时`Twitter`事件分析

# %% [markdown]
# - 安装
#
# ```python
# pip install pyalgotrade
# ```

# %%
from pyalgotrade import strategy # 策略
from pyalgotrade import plotter # 做图
from pyalgotrade.technical import ma # 技术方法
from pyalgotrade.technical import cross # 技术方法
from pyalgotrade.stratanalyzer import returns # 评价
from pyalgotrade.stratanalyzer import sharpe
from pyalgotrade.stratanalyzer import drawdown
from pyalgotrade.stratanalyzer import trades
from pyalgotrade.barfeed import membf,csvfeed
from pyalgotrade import bar
# import tushare as ts
import pandas as pd

class MyStrategy(strategy.BacktestingStrategy): # 继承策略的父类
    def __init__(self, feed, instrument, smaPeriod):
        super(MyStrategy, self).__init__(feed,100000)
        self.__instrument = instrument
        self.__closed = feed.getDataSeries().getCloseDataSeries()
        self.__ma = ma.SMA(self.__closed, smaPeriod)
        self.__position = None
       
    def getSMA(self):
        return self.__ma
   
    def onEnterCanceled(self, position):
        self.__position = None
        print("onEnterCanceled", position.getShares())
       
    def onExitOk(self, position):
        self.__position = None
        print("onExitOk", position.getShares())
       
    def onExitCanceled(self, position):
        self.__position.exitMarket()
        print("onExitCanceled", position.getShares())
       
    # 这个函数每天调一次
    def onBars(self, bars):
        bar = bars[self.__instrument] # bar是k线中的每个柱
        if self.__position is None: 
            if cross.cross_above(self.__closed, self.__ma) > 0:
                shares = int(self.getBroker().getCash() * 0.3 / bar.getPrice())
                print("cross_above shares,", shares)
                self.__position = self.enterLong(self.__instrument, shares, True)
        elif not self.__position.exitActive() and cross.cross_below(self.__closed, self.__ma) > 0:
            print("cross_below", bar.getPrice(), bar.getClose(), bar.getDateTime())
            # print(bars.keys())
            print("length", len(self.__closed), self.__closed[-1])
            self.__position.exitMarket()

    def getClose(self):
        return self.__closed

code = 'rb'
feed = csvfeed.GenericBarFeed(bar.Frequency.MONTH)
feed.addBarsFromCSV(code,'./data/performance/rb.csv')


myStrategy = MyStrategy(feed, code, 20) # 最重要的策略类
plt = plotter.StrategyPlotter(myStrategy) # 做图分析
plt.getInstrumentSubplot(code).addDataSeries("SMA", myStrategy.getSMA())

retAnalyzer = returns.Returns() # 评价
myStrategy.attachAnalyzer(retAnalyzer)
sharpeRatioAnalyzer = sharpe.SharpeRatio()
myStrategy.attachAnalyzer(sharpeRatioAnalyzer)
drawDownAnalyzer = drawdown.DrawDown()
myStrategy.attachAnalyzer(drawDownAnalyzer)
tradesAnalyzer = trades.Trades()
myStrategy.attachAnalyzer(tradesAnalyzer)

myStrategy.run() # 开始运行，然后事件驱动
myStrategy.info("最终投资组合价值: $%.2f" % myStrategy.getResult())

print("最终资产价值: $%.2f" % myStrategy.getResult())
print("累计回报率: %.2f %%" % (retAnalyzer.getCumulativeReturns()[-1] * 100))
print("夏普比率: %.2f" % (sharpeRatioAnalyzer.getSharpeRatio(0.05)))
print("最大回撤率: %.2f %%" % (drawDownAnalyzer.getMaxDrawDown() * 100))
print("最长回撤时间: %s" % (drawDownAnalyzer.getLongestDrawDownDuration()))

print("")
print("总交易 Total trades: %d" % (tradesAnalyzer.getCount()))
if tradesAnalyzer.getCount() > 0:
    profits = tradesAnalyzer.getAll()
    print("利润", "mean", round(profits.mean(),2), "std", round(profits.std(),2),
          "max", round(profits.max(),2), "min", round(profits.min(),2))
    returns = tradesAnalyzer.getAllReturns()
    print("收益率", "mean", round(returns.mean(),2), "std", round(returns.std(),2),
          "max", round(returns.max(),2), "min", round(returns.min(),2))
print("")
print("赢利交易 Profitable trades: %d" % (tradesAnalyzer.getProfitableCount()))
if tradesAnalyzer.getProfitableCount() > 0:
    profits = tradesAnalyzer.getProfits()
    print("利润", "mean", round(profits.mean(),2), "std", round(profits.std(),2),
          "max", round(profits.max(),2), "min", round(profits.min(),2))
    returns = tradesAnalyzer.getPositiveReturns()
    print("收益率", "mean", round(returns.mean(),2), "std", round(returns.std(),2),
          "max", round(returns.max(),2), "min", round(returns.min(),2))
print("")
print("亏损交易Unprofitable trades: %d" % (tradesAnalyzer.getUnprofitableCount()))
if tradesAnalyzer.getUnprofitableCount() > 0:
    losses = tradesAnalyzer.getLosses()
    print("利润", "mean", round(losses.mean(),2), "std", round(losses.std(),2),
          "max", round(losses.max(),2), "min", round(losses.min(),2))
    returns = tradesAnalyzer.getNegativeReturns()
    print("收益率", "mean", round(returns.mean(),2), "std", round(returns.std(),2),
          "max", round(returns.max(),2), "min", round(returns.min(),2))
  
plt.plot()
# Out:
# cross_above shares, 8
# cross_below 3424.0 3424.0 2019-12-05 14:44:00
# length 30 3424.0
# onExitOk 0
# cross_above shares, 8
# cross_below 3407.0 3407.0 2019-12-05 21:35:00
# length 83 3407.0
# onExitOk 0
# cross_above shares, 8
# cross_below 3407.0 3407.0 2019-12-05 21:39:00
# length 87 3407.0
# onExitOk 0
# cross_above shares, 8
# cross_below 
0
# onExitOk 0
# cross_above shares, 6
# cross_below 3814.0 3814.0 2020-09-01 09:10:00
# length 1024 3814.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3815.0 3815.0 2020-09-01 09:21:00
# length 1024 3815.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3813.0 3813.0 2020-09-01 09:33:00
# length 1024 3813.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3813.0 3813.0 2020-09-01 09:47:00
# length 1024 3813.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3813.0 3813.0 2020-09-01 09:53:00
# length 1024 3813.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3814.0 3814.0 2020-09-01 10:01:00
# length 1024 3814.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3814.0 3814.0 2020-09-01 10:06:00
# length 1024 3814.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3814.0 3814.0 2020-09-01 10:10:00
# length 1024 3814.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3815.0 3815.0 2020-09-01 10:30:00
# length 1024 3815.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3815.0 3815.0 2020-09-01 10:33:00
# length 1024 3815.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3812.0 3812.0 2020-09-01 10:47:00
# length 1024 3812.0
# onExitOk 0
# cross_above shares, 7
# cross_below 3806.0 3806.0 2020-09-01 11:12:00
# length 1024 3806.0
# onExitOk 0
# cross_above shares, 7
# cross_below 3805.0 3805.0 2020-09-01 11:14:00
# length 1024 3805.0
# onExitOk 0
# cross_above shares, 7
# cross_below 3805.0 3805.0 2020-09-01 11:16:00
# length 1024 3805.0
# onExitOk 0
# cross_above shares, 7
# cross_below 3805.0 3805.0 2020-09-01 11:23:00
# length 1024 3805.0
# onExitOk 0
# cross_above shares, 7
# cross_below 3806.0 3806.0 2020-09-01 11:25:00
# length 1024 3806.0
# onExitOk 0
# cross_above shares, 7
# cross_below 3806.0 3806.0 2020-09-01 11:28:00
# length 1024 3806.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3809.0 3809.0 2020-09-01 13:48:00
# length 1024 3809.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3810.0 3810.0 2020-09-01 13:56:00
# length 1024 3810.0
# onExitOk 0
# cross_above shares, 6
# cross_below 3810.0 3810.0 2020-09-01 14:00:00
# length 1024 3810.0
# onExitOk 0
# 最终资产价值: $88868.00
# 累计回报率: -11.13 %
# 夏普比率: -6.48
# 最大回撤率: 11.70 %
# 最长回撤时间: 267 days, 2:57:00
#
# 总交易 Total trades: 4149
# 利润 mean -2.68 std 40.29 max 744.0 min -296.0
# 收益率 mean -0.0 std 0.0 max 0.03 min -0.01
#
# 赢利交易 Profitable trades: 770
# 利润 mean 48.07 std 67.08 max 744.0 min 6.0
# 收益率 mean 0.0 std 0.0 max 0.03 min 0.0
#
# 亏损交易Unprofitable trades: 2741
# 利润 mean -17.57 std 15.68 max -6.0 min -296.0
# 收益率 mean -0.0 std 0.0 max -0.0 min -0.01

# %% [markdown]
# ### `PyAlgoTrade`的组成

# %% [markdown]
# <center><img src="./img/performance/pyalgotrade.png" width=100%></center>

# %% [markdown]
# - 数据源：数据接口
#     - k线历史价格数据
#     - Twitter的数据源，将 Tiwtter 的事件整合进交易决策中

# %% [markdown]
# - 券商：负责执行交易指令

# %% [markdown]
# - 数据序列：管理时间序列数据的接口

# %% [markdown]
# - 技术指标：基于数据序列而生成的一系列技术指标

# %% [markdown]
# - 优化器：可以实现在一台计算的多个进程中，或者多台计算机中运行回测

# %% [markdown]
# ### 策略

# %% [markdown]
# - 策略：实现交易逻辑的**类**

# %% [markdown]
# ```python
#
# from pyalgotrade import strategy
#
# class MyStrategy(strategy.BacktestingStrategy):
#     def __init__(self, feed, instrument):
#         super(MyStrategy, self).__init__(feed)   #父类的初始化
#         self.__instrument = instrument
#
#     def onBars(self, bars):# 每一个数据都会抵达这里，就像becktest中的next
#         bar = bars[self.__instrument]
#         self.info(bar.getClose())# 我们打印输出收盘价
# ```

# %% [markdown]
# #### 类与对象

# %% [markdown]
# - 面向对象编程（object oriented programming，OOP）：是一种程序设计思想。OOP把对象作为程序的基本单元，一个对象包含了数据和操作数据的函数

# %% [markdown]
# - 类是对象的抽象，对象是类的实例

# %% [markdown]
# ##### 定义类

# %% [markdown]
# - 用`class`关键字

# %% [markdown]
# ```python
# class Student(object):
#     pass
# ```

# %% [markdown]
# - 建立对象

# %% [markdown]
# ```python
# studentA = Student()
# studentB = Student()
# ```

# %% [markdown]
# ##### 定义属性

# %%
class Student(object):
    def __init__(self,name,gender,math,english):
        self.name = name
        self.gender = gender
        self.mathScore = math
        self.englishScore = english
        self.grade = 0

# %% [markdown]
# - `def __init__(self)`：初始化函数，建立对象的时候调用该函数，`self`**必不可少**

# %% [markdown]
# ###### 建立对象

# %%
studentA = Student('Mike','male',100,90)
studentB = Student('Suzen','female',80,95)

# %% [markdown]
# ###### 调用属性

# %%
studentA.name
studentB.name
studentA.mathScore
studentB.grade
# Out:
# 'Mike'
# 'Suzen'
# 100
# 0

# %% [markdown]
# ##### 定义方法

# %%
class Student(object):
    def __init__(self,name,gender,math,english):
        self.name = name
        self.gender = gender
        self.mathScore = math
        self.englishScore = english
        self.grade = 0
    def total_score(self):
        self.grade = self.mathScore + self.englishScore

# %% [markdown]
# ###### 建立对象

# %%
studentA = Student('Mike','male',100,90)
studentB = Student('Suzen','female',80,95)

# %% [markdown]
# ###### 调用方法

# %%
studentA.total_score()
studentB.total_score()
studentA.grade
studentB.grade
# Out:
# 190
# 175

# %% [markdown]
# ##### 定义更多方法

# %%
class Student(object):
    def __init__(self,name,gender,math,english):
        self.name = name
        self.gender = gender
        self.mathScore = math
        self.englishScore = english
        self.grade = 0
        
    def total_score(self):
        self.grade = self.mathScore + self.englishScore
    
    def show_grade(self):
        print(f'{self.name}的总成绩是{self.grade}')

# %%
studentLst = []
studentLst.append(Student('Mike','male',100,90))
studentLst.append(Student('Suzen','female',80,95))

# %%
for each in studentLst:
    each.total_score()
    each.show_grade()
# Out:
# Mike的总成绩是190
# Suzen的总成绩是175

# %% [markdown]
# #### 简单均线策略

# %% [markdown]
# - 如果收盘价**向上突破**30个周期均线，建立**多头头寸**
# - 如果收盘价**向下突破**30个周期均线，并且**已经有多头仓位**，那么**平掉该多头仓位**

# %% [markdown]
# ##### 建立策略类

# %% [markdown]
# ```python
# from pyalgotrade import strategy     # 导入策略基类
# from pyalgotrade.technical import ma # 导入技术指标中的均线
# ```

# %% [markdown]
# ###### 定义属性

# %% [markdown]
# ```python
# class MyStrategy(strategy.BacktestingStrategy):
#     def __init__(self, feed, instrument, smaPeriod):
#         super(MyStrategy, self).__init__(feed, 50000)  # feed：外部传入的时间序列数据, 50000:初始资金量
#         self.__position = None
#         self.__instrument = instrument
#         self.__sma = ma.SMA(feed[instrument].getPriceDataSeries(),smaPeriod)
# ```

# %% [markdown]
# - 属性
#     - `self.__position`：记录仓位
#     - `self.__instrument`：交易品种
#     - `self.__sma`：均线
#         - `feed[instrument].getPriceDataSeries()`：获得交易品种的收盘价序列数据
#         - `smaPeriod`：移动平均的时间窗口

# %% [markdown]
# ###### 定义方法：产生交易信号

# %% [markdown]
# ```python
# def onBars(self,bars):
#     pass
# ```

# %% [markdown]
# - 交易逻辑都要体现在该方法（函数）中
# - 唯一参数`bars`：字典类型，`key`是交易标的名称，`value`是当前周期的k线数据
# - k线数据：`Bar`类的对象，该类的方法包括
#     - `getDateTime()`
#     - `getOpen()`
#     - `getHigh()`
#     - `getLow()`
#     - `getClose()`
#     - `getVolume()`
#     - `getTypicalPrice()`
#     - `getPrice()`：获得收盘价（Close）或调整的收盘价（Adj. Close）

# %% [markdown]
# <center><img src="./img/performance/bars.png" width=100%></center>

# %% [markdown]
# - 属于同一个bars的所有bar的`Date Time`必须一样

# %% [markdown]
# ```python
#     def onBars(self,bars):
#         # 当移动均值存在的时候运行，否则返回
#         if self.__sma[-1] is None:
#             return
#
#         bar = bars[self.__instrument]  # 获取需要交易品种的当前k线数据
#         if self.__position is None:   # 判断当前是否有仓位
#             if bar.getPrice() > self.__sma[-1]:  # 建立多仓条件
#                 pass
#         elif bar.getPrice() < self.__sma[-1]:  # 平多仓条件
#             pass
# ```

# %% [markdown]
# - `self.__sma[-1]`：最新的移动平均值

# %% [markdown]
# ### 下单指令

# %% [markdown]
# #### 建仓

# %% [markdown]
# ##### 建仓交互过程

# %% [markdown]
# <center><img src="./img/performance/enterPosSeq.svg" width=100%></center>

# %% [markdown]
# ##### 建仓命令

# %% [markdown]
# ```python
#     Strategy.enterLong(self, instrument, quantity)
#     Strategy.enterShort(self, instrument, quantity)
# ```

# %% [markdown]
# - `instrument`：`str`类型，交易品种名称
# - `quantity`：`int`类型，下单的数量

# %% [markdown]
# - 执行市价单

# %% [markdown]
# - 返回的是一个仓位类的实例，即`Position`类的实例

# %% [markdown]
# ##### 持仓

# %% [markdown]
# - `Position`类，该类有如下方法

# %% [markdown]
# - `getShares()`：获取持仓的数量
#     - 正整数：多头仓位
#     - 负整数：空头仓位
#     - 0：仓位已经平掉，或者处于挂单状态，还未成交

# %% [markdown]
# - `getReturn(includeComissions=True)`：截至到当前时点，该仓位的累积收益率

# %% [markdown]
# - `getPnL(includeCommissions=True)`：截至到当前时点，该仓位的收益和损失（Profit and Loss）

# %% [markdown]
# - `getEntryOrder()`：获得建立该仓位对应的下单

# %% [markdown]
# - `getExitOrder()`：获得平掉该仓位对应的下单

# %% [markdown]
# ##### 建仓成功的回复

# %% [markdown]
# ```python
# Strategy.onEnterOK(self, Position)
# ```
#
# - 需要自定义内容的函数
# - 一般可以打印建仓的信息

# %% [markdown]
# #### 平仓

# %% [markdown]
# ##### 平仓交互过程

# %% [markdown]
# <center><img src="./img/performance/exitPosSeq.svg" width=80%></center>

# %% [markdown]
# ##### 平仓命令

# %% [markdown]
# - `Position.exitMarket()`：用**市价单**平掉仓位
# - 注意：`exitMarket()`是`Position`的方法

# %% [markdown]
# ##### 把建仓命令和平仓命令应用到策略中

# %% [markdown]
# ```python
#     def onBars(self,bars):
#         bar = bars[self.__instrument]  # 获取需要交易标的的当前k线数据
#         if self.__position is None:   # 判断当前是否有仓位
#             if bar.getPrice() > self.__sma[-1]:  # 建立多仓条件
#                 self.__position = self.enterLong(self.__instrument, 5)  # 建立多仓
#         elif bar.getPrice() < self.__sma[-1]:  # 平多仓条件
#             self.__position.exitMarket()  # 平仓
# ```

# %% [markdown]
# - 平仓之前还需要判断一下是否有平仓的挂单

# %% [markdown]
# ```python
#     def onBars(self,bars):
#         bar = bars[self.__instrument]  # 获取需要交易标的的当前k线数据
#         if self.__position is None:   # 判断当前是否有仓位
#             if bar.getPrice() > self.__sma[-1]:  # 建立多仓条件
#                 self.__position = self.enterLong(self.__instrument, 5)       # 建立5手多单
#         elif bar.getPrice() < self.__sma[-1] and not self.__position.exitActive():  # 平多仓条件 并且当前没有平仓的挂单
#             self.__position.exitMarket()
# ```

# %% [markdown]
# ##### 平仓成功的回复

# %% [markdown]
# ```python
#     Strategy.onExitOK(Position)
# ```
#
# - 需要自定义的函数

# %% [markdown]
# #### 查询是否有挂单

# %% [markdown]
# ##### 挂单

# %% [markdown]
# <center><img src="./img/performance/listing.jpg" width=100%></center>

# %% [markdown]
# ##### 查询是否有挂单交互过程

# %% [markdown]
# <center><img src="./img/performance/listOrderSeq.svg" width=100%></center>

# %% [markdown]
# ##### 查询挂单命令

# %% [markdown]
# ```python
#     # 查询是否有开仓挂单
#     Position.entryActive()
#     # 查询是否有平仓挂单
#     Position.exitActive()
# ```

# %% [markdown]
# - 如果有建仓（平仓）的挂单，返回`True`，否则为`False`

# %% [markdown]
# #### 查询下单是否成交

# %% [markdown]
# ##### 查询下单是否成交交互过程

# %% [markdown]
# <center><img src="./img/performance/filledOrderSeq.svg" width=100%></center>

# %% [markdown]
# ##### 查询是否成交命令

# %% [markdown]
# ```python
#     # 查询开仓单是否成交
#     Position.entryFilled()
#     # 查询平仓单是否成交
#     Position.exitFilled()
# ```

# %% [markdown]
# - 如果建仓（平仓）的挂单已经成交，返回`True`，否则为`False`

# %% [markdown]
# #### 撤销下单

# %% [markdown]
# ##### 撤单交互过程

# %% [markdown]
# <center><img src="./img/performance/cancelOrderSeq.svg" width=100%></center>

# %% [markdown]
# ##### 撤单命令

# %% [markdown]
# ```python
#     # 撤销开仓单
#     Position.cancelEntry()
#     # 撤销平仓单
#     Position.cancelExit()
# ```

# %% [markdown]
# ##### 撤单回复

# %% [markdown]
# ```python
#     # 撤销开仓单的回复
#     Strategy.onEnterCanceled(self, Position)
#     # 撤销平仓单的回复
#     Strategy.onExitCanceled(self, Position)
# ```
#
# - 均是需要自定义的函数

# %% [markdown]
# ### 券商

# %% [markdown]
# - 下单管理模块

# %% [markdown]
# #### `Order`类

# %% [markdown]
# - 该类的方法
#     - `getType()`：获取该订单的类型，包括市价单(MARKET)、限价单(LIMIT)、止损单(STOP)等
#     - `getAction()`：获取该订单执行的方向，包括BUY、BUY_TO_COVER、SELL、SELL_SHORT
#     - `getState()`：获取该订单的状态，包括提交(SUBMITTED)、被交易所接收(ACCEPTED)、撤销(CANCELED)、成交(FILLED)等
#     - `getExecutionInfo()`：获取订单的执行信息，返回`OrderExecutionInfo`类的对象

# %% [markdown]
# #### `OrderExecutionInfo`类

# %% [markdown]
# - 该类的方法
#     - `getPrice()`：实际成交价格
#     - `getQuantity()`：实际成交数量

# %% [markdown]
# #### 自定义开仓成功和平仓成功函数

# %% [markdown]
# ```python
#     def onEnterOK(self, position):
#         execInfo = position.getEntryOrder().getExecutionInfo()
#         self.info(f'建多仓，价格为{execInfo.getPrice()：.2f}，数量为{execInfo.getQuantity()}')
# ```

# %% [markdown]
# ```python
#     def onExitOK(position):
#         execInfo = position.getExitOrder().getExecutionInfo()
#         self.info(f'平多仓，价格为{execInfo.getPrice():.2f}，数量为{execInfo.getQuantity()}')
#         self.__position = None   # 清空仓位
# ```

# %% [markdown]
# #### 完整策略

# %% [markdown]
# ```python
#     from pyalgotrade import strategy
#     from pyalgotrade.technical import ma
#
#     class MyStrategy(strategy.BacktestingStrategy):
#         def __init__(self, feed, instrument, smaPeriod):
#             super(MyStrategy, self).__init__(feed, 50000)
#             self.__position = None
#             self.__instrument = instrument
#             self.__sma = ma.SMA(feed[instrument].getPriceDataSeries(), smaPeriod)
#
#         def onEnterOk(self, position):
#             execInfo = position.getEntryOrder().getExecutionInfo()
#             self.info(f'建多仓，价格为{execInfo.getPrice():.2f}，数量为{execInfo.getQuantity()}')
#
#         def onExitOk(self, position):
#             execInfo = position.getExitOrder().getExecutionInfo()
#             self.info(f'平多仓，价格为{execInfo.getPrice():.2f}，数量为{execInfo.getQuantity()}')
#             self.__position = None
#
#         def onBars(self, bars):
#             if self.__sma[-1] is None:
#                 return
#
#             bar = bars[self.__instrument]
#             if self.__position is None:
#                 if bar.getPrice() > self.__sma[-1]:
#                     self.__position = self.enterLong(self.__instrument, 5)
#             elif bar.getPrice() < self.__sma[-1] and not self.__position.exitActive():
#                 self.__position.exitMarket()
# ```

# %% [markdown]
# ### 数据源

# %% [markdown]
# - `feed`类实现数据源管理，主要功能包括：
#     - 读取`csv`格式存储的交易数据
#     - 在策略的事件循环中产生新的数据

# %% [markdown]
# #### 生成`feed`类

# %% [markdown]
# ```python
#     pyalgotrade.barfeed.yahoofeed.Feed(frequency=86400)
# ```
# - `frequency`：交易数据的频率，支持“天”、“周”。默认频率是“天”，24小时=86400秒；如果希望频率设为“周”，则`frequency=86400*7`
# - 读入从yahoo下载保存成`csv`格式的交易数据

# %% [markdown]
# - 建立一个读取yahoo存储为`csv`文件的`feed`类，用默认频率“天”
# ```python
#     from pyalgotrade.barfeed import yahoofeed
#     feed = yahoofeed.Feed()
# ```

# %% [markdown]
# #### 加载数据

# %% [markdown]
# - `feed`类的方法
# ```python
#    addBarsFromCSV(instrument,path)
# ```
# - `instrument`：交易标的的名称，自己定义名称
# - `path`：数据文件的路径

# %% [markdown]
# - 给建立的`feed`类的对象加载`rb`的交易数据
#
# ```python
#     feed.addBarsFromCSV('maotai','./data/performance/maotai.csv')
# ```

# %%
mtstock = web.DataReader('600519.SS','yahoo',start='2010-1-1',end='2020-11-20')
mtstock
mtstock.shape
# Out:
#                    High          Low         Open        Close     Volume  \
# Date
# 2010-01-04   129.225998   127.205002   129.225998   127.678001  5896980.0
# 2010-01-05   128.850006   126.972000   128.466995   127.303001  4194404.0
# 2010-01-06   127.348000   124.950996   126.964996   125.289001  5309230.0
# 2010-01-07   125.612000   121.623001   125.289001   123.004997  6498681.0
# 2010-01-08   123.216003   120.285004   123.216003   121.712997  4885048.0
# ...                 ...          ...          ...          ...        ...
# 2020-11-16  1730.050049  1697.260010  1711.000000  1730.050049  3061349.0
# 2020-11-17  1742.349976  1701.069946  1740.000000  1715.800049  2522403.0
# 2020-11-18  1720.530029  1683.160034  1715.000000  1693.650024  3517895.0
# 2020-11-19  1725.000000  1680.599976  1684.500000  1720.189941  2781576.0
# 2020-11-20  1736.000000  1712.650024  1720.000000  1719.959961  2187466.0
#
#               Adj Close
# Date
# 2010-01-04   103.709641
# 2010-01-05   103.405045
# 2010-01-06   101.769127
# 2010-01-07    99.913879
# 2010-01-08    98.864426
# ...                 ...
# 2020-11-16  1730.050049
# 2020-11-17  1715.800049
# 2020-11-18  1693.650024
# 2020-11-19  1720.189941
# 2020-11-20  1719.959961
#
# [2643 rows x 6 columns]
# (2643, 6)

# %%
mtstock.loc['2019-01-07','Low'], mtstock.loc['2019-01-07','Open'] = mtstock.loc['2019-01-07','Open'], mtstock.loc['2019-01-07','Low']

# %%
mtstock.drop(mtstock.loc[mtstock['Volume']==0].index,inplace=True)

# %%
mtstock.to_csv('./data/performance/maotai.csv')

# %% [markdown]
# #### 获取k线序列

# %% [markdown]
# ```python
#     feed[instrument]
# ```
# - 返回的是`BarDataSeries`类的对象，即由k线构成的时间序列数据

# %% [markdown]
# <center><img src="./img/performance/barDataSeries.png" width=100%></center>

# %% [markdown]
# - 该类的主要方法
#     - `getCloseDataSeries()`
#     - `getHighDataSeries()`
#     - `getLowDataSeries()`
#     - `getOpenDataSeries()`
#     - `getVolumeDataSeries()`
# - 均返回的是`pyalgotrade.dataseries.DataSeries`类的对象

# %% [markdown]
# ### 技术分析

# %% [markdown]
# #### 趋势指标

# %% [markdown]
# ```python
#     pyalgotrade.technical.ma.SMA(dataSeries, period)
# ```
# - 简单移动平均
# - `dataSeries`：***`DataSeries`***类的数据序列
# - `period`：时间窗口长度

# %% [markdown]
# ```python
#     pyalgotrade.technical.ma.EMA(dataSeries, period)
# ```
# - 指数移动平均
# - `dataSeries`：***`DataSeries`***类的数据序列
# - `period`：时间窗口长度

# %% [markdown]
# ```python
#     pyalgotrade.technical.macd.MACD(dataSeries, fastEMA, slowEMA, signalEMA)
# ```
# - `dataSeries`：***`DataSeries`***类的数据序列
# - `fastEMA`：短期时间窗口长度
# - `slowEMA`：长期时间窗口长度
# - `signalEMA`：信号线时间窗口长度

# %% [markdown]
# - 方法
#     - `getHistogram()`：获得`MACD`线与`Signal`线之间的差
#     - `getSignal()`：获得信号线的`DataSeries`数据序列

# %% [markdown]
# #### 能量指标

# %% [markdown]
# ```python
#     pyalgotrade.technical.rsi.RSI(dataSeries, period)
# ```
# - `dataSeries`：***`DataSeries`***类的数据序列
# - `period`：时间窗口长度

# %% [markdown]
# #### 波动性指标

# %% [markdown]
# ```python
#     pyalgotrade.technical.atr.ATR(barDataSeries, period)
# ```
# - `barDataSeries`：***`BarDataSeries`***类的数据序列
# - `period`：时间窗口长度

# %% [markdown]
# ```python
#     pyalgotrade.technical.bollinger.BollingerBands(dataSeries, period，numStdDev)
# ```
# - `dataSeries`：***`DataSeries`***类的数据序列
# - `period`：时间窗口长度
# - `numStdDev`：标准差的倍数

# %% [markdown]
# - 方法
#     - `getLowerBand()`：获得Bollinger的下界
#     - `getUpperBand()`：获得Bollinger的上界
#     - `getMiddleBand()`：获得Bollinger的中线

# %% [markdown]
# #### 其他指标

# %% [markdown]
# ```python
#     pyalgotrade.technical.highlow.High(dataSeries, period)
# ```
# - 计算时间窗口内的**最高值**
# - `dataSeries`：***`DataSeries`***类的数据序列
# - `period`：时间窗口长度

# %% [markdown]
# ```python
#     pyalgotrade.technical.highlow.Low(dataSeries, period)
# ```
# - 计算时间窗口内的**最低值**
# - `dataSeries`：***`DataSeries`***类的数据序列
# - `period`：时间窗口长度

# %% [markdown]
# #### 调用`TA-Lib`

# %% [markdown]
# - 通过`pyalgotrade.talibext.indicator`实现对`TA-Lib`的调用

# %% [markdown]
# ```python
#     pyalgotrade.talibext.indicator.BBANDS(ds, count, matype)
# ```
# - `ds`：***`DataSeries`***类的数据序列
# - `count`：需要用到的数据数量

# %% [markdown]
# ```python
#     pyalgotrade.talibext.indicator.ATR(barDs, count, timeperiod)
# ```
# - `barDs`：***`BarDataSeries`***类型的数据序列
# - `count`：需要用到的数据数量
# - `timeperiod`：时间窗口长度

# %% [markdown]
# ### 运行策略

# %% [markdown]
# ```python
#     Strategy.run()
# ```
# - 运行策略，仅能调用**一次**

# %% [markdown]
# - 建立策略类

# %%
from pyalgotrade import strategy
from pyalgotrade.technical import ma

class MyStrategy(strategy.BacktestingStrategy):
    def __init__(self, feed, instrument, smaPeriod):
        super(MyStrategy, self).__init__(feed, 50000)
        self.__position = None
        self.__instrument = instrument
        self.__sma = ma.SMA(feed[instrument].getPriceDataSeries(), smaPeriod)

    def onEnterOk(self, position):
        execInfo = position.getEntryOrder().getExecutionInfo()
        self.info(f'建多仓，价格为{execInfo.getPrice():.2f}，数量为{execInfo.getQuantity()}')

    def onExitOk(self, position):
        execInfo = position.getExitOrder().getExecutionInfo()
        self.info(f'平多仓，价格为{execInfo.getPrice():.2f}，数量为{execInfo.getQuantity()}，PnL为{position.getPnL():.2f}')
        self.__position = None
        
    def onFinish(self, bars):
        self.warning('回测完毕！')

    def onBars(self, bars):
        if self.__sma[-1] is None:
            return
        bar = bars[self.__instrument]
        if self.__position is None:
            if bar.getPrice() > self.__sma[-1]:
                self.__position = self.enterLong(self.__instrument, 5)
        elif bar.getPrice() < self.__sma[-1] and not self.__position.exitActive():
            self.__position.exitMarket()

# %% [markdown]
# - 建立数据源并读入数据

# %%
from pyalgotrade.barfeed import yahoofeed
myfeed = yahoofeed.Feed()
myfeed.addBarsFromCSV('maotai','./data/performance/maotai.csv')

# %% [markdown]
# - 建立策略对象并初始化

# %%
myStrategy = MyStrategy(myfeed,'maotai',30)

# %% [markdown]
# - 运行策略

# %%
myStrategy.run()
# Out:
# 2010-02-22 00:00:00 strategy [INFO] 建多仓，价格为129.98，数量为5
# 2010-02-24 00:00:00 strategy [INFO] 平多仓，价格为125.29，数量为5，PnL为-23.44
# 2010-02-25 00:00:00 strategy [INFO] 建多仓，价格为125.39，数量为5
# 2010-03-01 00:00:00 strategy [INFO] 平多仓，价格为125.06，数量为5，PnL为-1.69
# 2010-06-04 00:00:00 strategy [INFO] 建多仓，价格为101.38，数量为5
# 2010-06-21 00:00:00 strategy [INFO] 平多仓，价格为99.47，数量为5，PnL为-9.50
# 2010-06-22 00:00:00 strategy [INFO] 建多仓，价格为100.12，数量为5
# 2010-06-23 00:00:00 strategy [INFO] 平多仓，价格为99.17，数量为5，PnL为-4.73
# 2010-07-19 00:00:00 strategy [INFO] 建多仓，价格为99.96，数量为5
# 2010-10-14 00:00:00 strategy [INFO] 平多仓，价格为119.38，数量为5，PnL为97.11
# 2010-10-21 00:00:00 strategy [INFO] 建多仓，价格为125.92，数量为5
# 2010-11-01 00:00:00 strategy [INFO] 平多仓，价格为122.61，数量为5，PnL为-16.53
# 2010-11-10 00:00:00 strategy [INFO] 建多仓，价格为125.17，数量为5
# 2010-11-18 00:00:00 strategy [INFO] 平多仓，价格为125.13，数量为5，PnL为-0.19
# 2010-11-19 00:00:00 strategy [INFO] 建多仓，价格为128.55，数量为5
# 2010-12-23 00:00:00 strategy [INFO] 平多仓，价格为143.39，数量为5，PnL为74.19
# 2011-02-09 00:00:00 strategy [INFO] 建多仓，价格为135.23，数量为5
# 2011-02-10 00:00:00 strategy [INFO] 平多仓，价格为133.25，数量为5，PnL为-9.92
# 2011-02-11 00:00:00 strategy [INFO] 建多仓，价格为138.80，数量为5
# 2011-03-01 00:00:00 strategy [INFO] 平多仓，价格为134.27，数量为5，PnL为-22.66
# 2011-03-11 00:00:00 strategy [INFO] 建多仓，价格为136.44，数量为5
# 2011-03-16 00:00:00 strategy [INFO] 平多仓，价格为134.94，数量为5，PnL为-7.51
# 2011-03-17 00:00:00 strategy [INFO] 建多仓，价格为135.91，数量为5
# 2011-03-29 00:00:00 strategy [INFO] 平多仓，价格为135.99，数量为5，PnL为0.38
# 2011-04-26 00:00:00 strategy [INFO] 建多仓，价格为137.49，数量为5
# 2011-04-29 00:00:00 strategy [INFO] 平多仓，价格为134.04，数量为5，PnL为-17.28
# 2011-05-03 00:00:00 strategy [INFO] 建多仓，价格为137.49，数量为5
# 2011-09-06 00:00:00 strategy [INFO] 平多仓，价格为170.25，数量为5，PnL为163.79
# 2011-10-25 00:00:00 strategy [INFO] 建多仓，价格为164.63，数量为5
# 2011-12-07 00:00:00 strategy [INFO] 平多仓，价格为168.35，数量为5，PnL为18.59
# 2012-02-10 00:00:00 strategy [INFO] 建多仓，价格为156.64，数量为5
# 2012-04-05 00:00:00 strategy [INFO] 平多仓，价格为162.07，数量为5，PnL为27.15
# 2012-04-06 00:00:00 strategy [INFO] 建多仓，价格为169.93，数量为5
# 2012-05-21 00:00:00 strategy [INFO] 平多仓，价格为179.82，数量为5，PnL为49.42
# 2012-05-22 00:00:00 strategy [INFO] 建多仓，价格为185.96，数量为5
# 2012-05-25 00:00:00 strategy [INFO] 平多仓，价格为182.02，数量为5，PnL为-19.71
# 2012-05-30 00:00:00 strategy [INFO] 建多仓，价格为188.02，数量为5
# 2012-07-19 00:00:00 strategy [INFO] 平多仓，价格为201.65，数量为5，PnL为68.10
# 2012-07-25 00:00:00 strategy [INFO] 建多仓，价格为206.61，数量为5
# 2012-08-01 00:00:00 strategy [INFO] 平多仓，价格为203.46，数量为5，PnL为-15.78
# 2012-08-08 00:00:00 strategy [INFO] 建多仓，价格为208.65，数量为5
# 2012-08-13 00:00:00 strategy [INFO] 平多仓，价格为205.35，数量为5，PnL为-16.45
# 2012-09-10 00:00:00 strategy [INFO] 建多仓，价格为199.76，数量为5
# 2012-09-20 00:00:00 strategy [INFO] 平多仓，价格为190.83，数量为5，PnL为-44.67
# 2012-09-26 00:00:00 strategy [INFO] 建多仓，价格为196.69，数量为5
# 2012-10-29 00:00:00 strategy [INFO] 平多仓，价格为199.66，数量为5，PnL为14.83
# 2012-10-31 00:00:00 strategy [INFO] 建多仓，价格为202.08，数量为5
# 2012-11-06 00:00:00 strategy [INFO] 平多仓，价格为200.34，数量为5，PnL为-8.72
# 2012-12-20 00:00:00 strategy [INFO] 建多仓，价格为180.58，数量为5
# 2012-12-25 00:00:00 strategy [INFO] 平多仓，价格为167.69，数量为5，PnL为-64.46
# 2012-12-31 00:00:00 strategy [INFO] 建多仓，价格为176.29，数量为5
# 2013-01-04 00:00:00 strategy [INFO] 平多仓，价格为175.21，数量为5，PnL为-5.41
# 2013-01-09 00:00:00 strategy [INFO] 建多仓，价格为174.79，数量为5
# 2013-01-17 00:00:00 strategy [INFO] 平多仓，价格为169.41，数量为5，PnL为-26.90
# 2013-03-08 00:00:00 strategy [INFO] 建多仓，价格为153.73，数量为5
# 2013-03-15 00:00:00 strategy [INFO] 平多仓，价格为146.71，数量为5，PnL为-35.08
# 2013-04-15 00:00:00 strategy [INFO] 建多仓，价格为142.37，数量为5
# 2013-06-17 00:00:00 strategy [INFO] 平多仓，价格为160.55，数量为5，PnL为90.91
# 2013-07-03 00:00:00 strategy [INFO] 建多仓，价格为164.38，数量为5
# 2013-07-09 00:00:00 strategy [INFO] 平多仓，价格为162.23，数量为5，PnL为-10.75
# 2013-07-12 00:00:00 strategy [INFO] 建多仓，价格为161.25，数量为5
# 2013-07-15 00:00:00 strategy [INFO] 平多仓，价格为156.51，数量为5，PnL为-23.68
# 2013-10-22 00:00:00 strategy [INFO] 建多仓，价格为119.67，数量为5
# 2013-10-23 00:00:00 strategy [INFO] 平多仓，价格为118.40，数量为5，PnL为-6.36
# 2013-10-24 00:00:00 strategy [INFO] 建多仓，价格为118.43，数量为5
# 2013-10-28 00:00:00 strategy [INFO] 平多仓，价格为112.21，数量为5，PnL为-31.08
# 2013-11-07 00:00:00 strategy [INFO] 建多仓，价格为115.17，数量为5
# 2013-11-11 00:00:00 strategy [INFO] 平多仓，价格为114.05，数量为5，PnL为-5.62
# 2013-11-12 00:00:00 strategy [INFO] 建多仓，价格为115.22，数量为5
# 2013-11-22 00:00:00 strategy [INFO] 平多仓，价格为114.60，数量为5，PnL为-3.14
# 2013-11-26 00:00:00 strategy [INFO] 建多仓，价格为116.52，数量为5
# 2013-11-27 00:00:00 strategy [INFO] 平多仓，价格为115.69，数量为5，PnL为-4.14
# 2013-11-29 00:00:00 strategy [INFO] 建多仓，价格为116.53，数量为5
# 2013-12-03 00:00:00 strategy [INFO] 平多仓，价格为112.85，数量为5，PnL为-18.39
# 2014-01-21 00:00:00 strategy [INFO] 建多仓，价格为104.13，数量为5
# 2014-03-31 00:00:00 strategy [INFO] 平多仓，价格为125.63，数量为5，PnL为107.48
# 2014-04-02 00:00:00 strategy [INFO] 建多仓，价格为134.50，数量为5
# 2014-04-28 00:00:00 strategy [INFO] 平多仓，价格为133.95，数量为5，PnL为-2.73
# 2014-06-24 00:00:00 strategy [INFO] 建多仓，价格为129.44，数量为5
# 2014-08-20 00:00:00 strategy [INFO] 平多仓，价格为144.31，数量为5，PnL为74.36
# 2014-08-21 00:00:00 strategy [INFO] 建多仓，价格为147.27，数量为5
# 2014-08-22 00:00:00 strategy [INFO] 平多仓，价格为145.46，数量为5，PnL为-9.09
# 2014-09-03 00:00:00 strategy [INFO] 建多仓，价格为147.80，数量为5
# 2014-09-16 00:00:00 strategy [INFO] 平多仓，价格为145.91，数量为5，PnL为-9.46
# 2014-09-26 00:00:00 strategy [INFO] 建多仓，价格为146.82，数量为5
# 2014-10-10 00:00:00 strategy [INFO] 平多仓，价格为144.56，数量为5，PnL为-11.27
# 2014-11-17 00:00:00 strategy [INFO] 建多仓，价格为152.73，数量为5
# 2014-11-19 00:00:00 strategy [INFO] 平多仓，价格为141.43，数量为5，PnL为-56.50
# 2014-11-27 00:00:00 strategy [INFO] 建多仓，价格为140.91，数量为5
# 2015-01-20 00:00:00 strategy [INFO] 平多仓，价格为160.02，数量为5，PnL为95.55
# 2015-02-10 00:00:00 strategy [INFO] 建多仓，价格为168.00，数量为5
# 2015-02-11 00:00:00 strategy [INFO] 平多仓，价格为165.82，数量为5，PnL为-10.91
# 2015-02-13 00:00:00 strategy [INFO] 建多仓，价格为167.37，数量为5
# 2015-02-16 00:00:00 strategy [INFO] 平多仓，价格为165.95，数量为5，PnL为-7.14
# 2015-02-17 00:00:00 strategy [INFO] 建多仓，价格为166.86，数量为5
# 2015-06-08 00:00:00 strategy [INFO] 平多仓，价格为228.65，数量为5，PnL为308.91
# 2015-06-09 00:00:00 strategy [INFO] 建多仓，价格为240.91，数量为5
# 2015-06-17 00:00:00 strategy [INFO] 平多仓，价格为230.87，数量为5，PnL为-50.18
# 2015-06-25 00:00:00 strategy [INFO] 建多仓，价格为237.73，数量为5
# 2015-06-26 00:00:00 strategy [INFO] 平多仓，价格为227.29，数量为5，PnL为-52.18
# 2015-07-10 00:00:00 strategy [INFO] 建多仓，价格为233.64，数量为5
# 2015-07-15 00:00:00 strategy [INFO] 平多仓，价格为225.00，数量为5，PnL为-43.18
# 2015-09-15 00:00:00 strategy [INFO] 建多仓，价格为198.01，数量为5
# 2015-09-24 00:00:00 strategy [INFO] 平多仓，价格为195.80，数量为5，PnL为-11.05
# 2015-10-09 00:00:00 strategy [INFO] 建多仓，价格为198.78，数量为5
# 2015-11-25 00:00:00 strategy [INFO] 平多仓，价格为211.70，数量为5，PnL为64.60
# 2015-11-26 00:00:00 strategy [INFO] 建多仓，价格为213.49，数量为5
# 2015-11-30 00:00:00 strategy [INFO] 平多仓，价格为208.04，数量为5，PnL为-27.25
# 2015-12-01 00:00:00 strategy [INFO] 建多仓，价格为213.00，数量为5
# 2015-12-02 00:00:00 strategy [INFO] 平多仓，价格为214.48，数量为5，PnL为7.40
# 2015-12-03 00:00:00 strategy [INFO] 建多仓，价格为219.00，数量为5
# 2015-12-08 00:00:00 strategy [INFO] 平多仓，价格为214.55，数量为5，PnL为-22.25
# 2015-12-18 00:00:00 strategy [INFO] 建多仓，价格为215.50，数量为5
# 2016-01-05 00:00:00 strategy [INFO] 平多仓，价格为210.00，数量为5，PnL为-27.50
# 2016-02-22 00:00:00 strategy [INFO] 建多仓，价格为206.00，数量为5
# 2016-04-21 00:00:00 strategy [INFO] 平多仓，价格为240.50，数量为5，PnL为172.50
# 2016-04-25 00:00:00 strategy [INFO] 建多仓，价格为247.12，数量为5
# 2016-05-19 00:00:00 strategy [INFO] 平多仓，价格为245.16，数量为5，PnL为-9.80
# 2016-05-23 00:00:00 strategy [INFO] 建多仓，价格为249.72，数量为5
# 2016-08-05 00:00:00 strategy [INFO] 平多仓，价格为306.49，数量为5，PnL为283.85
# 2016-08-10 00:00:00 strategy [INFO] 建多仓，价格为315.05，数量为5
# 2016-08-17 00:00:00 strategy [INFO] 平多仓，价格为309.60，数量为5，PnL为-27.25
# 2016-09-01 00:00:00 strategy [INFO] 建多仓，价格为309.70，数量为5
# 2016-09-02 00:00:00 strategy [INFO] 平多仓，价格为308.00，数量为5，PnL为-8.50
# 2016-09-07 00:00:00 strategy [INFO] 建多仓，价格为309.68，数量为5
# 2016-09-08 00:00:00 strategy [INFO] 平多仓，价格为305.21，数量为5，PnL为-22.35
# 2016-10-11 00:00:00 strategy [INFO] 建多仓，价格为304.00，数量为5
# 2016-11-18 00:00:00 strategy [INFO] 平多仓，价格为311.16，数量为5，PnL为35.80
# 2016-11-24 00:00:00 strategy [INFO] 建多仓，价格为313.20，数量为5
# 2016-12-26 00:00:00 strategy [INFO] 平多仓，价格为319.03，数量为5，PnL为29.15
# 2016-12-27 00:00:00 strategy [INFO] 建多仓，价格为324.51，数量为5
# 2017-07-04 00:00:00 strategy [INFO] 平多仓，价格为458.96，数量为5，PnL为672.25
# 2017-07-21 00:00:00 strategy [INFO] 建多仓，价格为466.96，数量为5
# 2017-09-07 00:00:00 strategy [INFO] 平多仓，价格为485.31，数量为5，PnL为91.75
# 2017-09-14 00:00:00 strategy [INFO] 建多仓，价格为492.99，数量为5
# 2017-11-27 00:00:00 strategy [INFO] 平多仓，价格为634.00，数量为5，PnL为705.05
# 2017-11-29 00:00:00 strategy [INFO] 建多仓，价格为649.94，数量为5
# 2017-11-30 00:00:00 strategy [INFO] 平多仓，价格为635.51，数量为5，PnL为-72.15
# 2017-12-12 00:00:00 strategy [INFO] 建多仓，价格为658.70，数量为5
# 2018-02-05 00:00:00 strategy [INFO] 平多仓，价格为727.22，数量为5，PnL为342.60
# 2018-03-02 00:00:00 strategy [INFO] 建多仓，价格为738.00，数量为5
# 2018-03-05 00:00:00 strategy [INFO] 平多仓，价格为738.18，数量为5，PnL为0.90
# 2018-03-16 00:00:00 strategy [INFO] 建多仓，价格为747.60，数量为5
# 2018-03-26 00:00:00 strategy [INFO] 平多仓，价格为708.00，数量为5，PnL为-198.00
# 2018-05-08 00:00:00 strategy [INFO] 建多仓，价格为698.03，数量为5
# 2018-06-20 00:00:00 strategy [INFO] 平多仓，价格为741.00，数量为5，PnL为214.85
# 2018-06-21 00:00:00 strategy [INFO] 建多仓，价格为765.22，数量为5
# 2018-06-27 00:00:00 strategy [INFO] 平多仓，价格为752.00，数量为5，PnL为-66.10
# 2018-07-17 00:00:00 strategy [INFO] 建多仓，价格为757.00，数量为5
# 2018-07-18 00:00:00 strategy [INFO] 平多仓，价格为742.43，数量为5，PnL为-72.85
# 2018-07-25 00:00:00 strategy [INFO] 建多仓，价格为746.95，数量为5
# 2018-07-27 00:00:00 strategy [INFO] 平多仓，价格为736.00，数量为5，PnL为-54.75
# 2018-07-30 00:00:00 strategy [INFO] 建多仓，价格为738.90，数量为5
# 2018-07-31 00:00:00 strategy [INFO] 平多仓，价格为720.30，数量为5，PnL为-93.00
# 2018-09-19 00:00:00 strategy [INFO] 建多仓，价格为666.58，数量为5
# 2018-10-11 00:00:00 strategy [INFO] 平多仓，价格为635.01，数量为5，PnL为-157.85
# 2018-10-22 00:00:00 strategy [INFO] 建多仓，价格为675.00，数量为5
# 2018-10-24 00:00:00 strategy [INFO] 平多仓，价格为628.11，数量为5，PnL为-234.45
# 2018-12-04 00:00:00 strategy [INFO] 建多仓，价格为602.99，数量为5
# 2018-12-24 00:00:00 strategy [INFO] 平多仓，价格为563.50，数量为5，PnL为-197.45
# 2019-01-02 00:00:00 strategy [INFO] 建多仓，价格为609.98，数量为5
# 2019-05-09 00:00:00 strategy [INFO] 平多仓，价格为875.00，数量为5，PnL为1325.10
# 2019-05-13 00:00:00 strategy [INFO] 建多仓，价格为898.86，数量为5
# 2019-05-14 00:00:00 strategy [INFO] 平多仓，价格为885.00，数量为5，PnL为-69.30
# 2019-05-16 00:00:00 strategy [INFO] 建多仓，价格为919.00，数量为5
# 2019-05-20 00:00:00 strategy [INFO] 平多仓，价格为900.00，数量为5，PnL为-95.00
# 2019-06-12 00:00:00 strategy [INFO] 建多仓，价格为906.22，数量为5
# 2019-07-19 00:00:00 strategy [INFO] 平多仓，价格为955.00，数量为5，PnL为243.90
# 2019-07-30 00:00:00 strategy [INFO] 建多仓，价格为976.50，数量为5
# 2019-08-01 00:00:00 strategy [INFO] 平多仓，价格为976.51，数量为5，PnL为0.05
# 2019-08-13 00:00:00 strategy [INFO] 建多仓，价格为1016.16，数量为5
# 2019-10-25 00:00:00 strategy [INFO] 平多仓，价格为1153.30，数量为5，PnL为685.70
# 2019-10-28 00:00:00 strategy [INFO] 建多仓，价格为1166.01，数量为5
# 2019-11-25 00:00:00 strategy [INFO] 平多仓，价格为1188.05，数量为5，PnL为110.20
# 2019-12-31 00:00:00 strategy [INFO] 建多仓，价格为1183.00，数量为5
# 2020-01-03 00:00:00 strategy [INFO] 平多仓，价格为1117.00，数量为5，PnL为-330.00
# 2020-02-20 00:00:00 strategy [INFO] 建多仓，价格为1096.70，数量为5
# 2020-02-26 00:00:00 strategy [INFO] 平多仓，价格为1062.00，数量为5，PnL为-173.50
# 2020-02-28 00:00:00 strategy [INFO] 建多仓，价格为1070.30，数量为5
# 2020-03-02 00:00:00 strategy [INFO] 平多仓，价格为1050.11，数量为5，PnL为-100.95
# 2020-03-03 00:00:00 strategy [INFO] 建多仓，价格为1098.00，数量为5
# 2020-03-17 00:00:00 strategy [INFO] 平多仓，价格为1055.00，数量为5，PnL为-215.00
# 2020-04-01 00:00:00 strategy [INFO] 建多仓，价格为1117.00，数量为5
# 2020-08-10 00:00:00 strategy [INFO] 平多仓，价格为1627.97，数量为5，PnL为2554.85
# 2020-08-18 00:00:00 strategy [INFO] 建多仓，价格为1697.38，数量为5
# 2020-08-21 00:00:00 strategy [INFO] 平多仓，价格为1673.00，数量为5，PnL为-121.90
# 2020-08-24 00:00:00 strategy [INFO] 建多仓，价格为1699.94，数量为5
# 2020-09-10 00:00:00 strategy [INFO] 平多仓，价格为1703.74，数量为5，PnL为19.00
# 2020-09-11 00:00:00 strategy [INFO] 建多仓，价格为1688.00，数量为5
# 2020-09-18 00:00:00 strategy [INFO] 平多仓，价格为1665.00，数量为5，PnL为-115.00
# 2020-10-13 00:00:00 strategy [INFO] 建多仓，价格为1750.62，数量为5
# 2020-10-19 00:00:00 strategy [INFO] 平多仓，价格为1725.00，数量为5，PnL为-128.10
# 2020-10-21 00:00:00 strategy [INFO] 建多仓，价格为1734.10，数量为5
# 2020-10-27 00:00:00 strategy [INFO] 平多仓，价格为1643.00，数量为5，PnL为-455.50
# 2020-11-04 00:00:00 strategy [INFO] 建多仓，价格为1700.00，数量为5
# 2020-11-19 00:00:00 strategy [INFO] 平多仓，价格为1684.50，数量为5，PnL为-77.50
# 2020-11-20 00:00:00 strategy [INFO] 建多仓，价格为1720.00，数量为5
# 2020-11-23 19:15:22,505 strategy [WARNING] 回测完毕！

# %% [markdown]
# - 最终权益

# %% [markdown]
# ```python
#     Strategy.getResult()
# ```

# %%
print(f"简单均线策略的最终权益为{myStrategy.getResult():.2f}")
# Out:
# 简单均线策略的最终权益为54859.34

# %% [markdown]
# ### 绩效评估

# %% [markdown]
# - 利用`pyalgotrade.stratanalyzer`类进行策略评估

# %% [markdown]
# <center><img src="./img/performance/analyzer.png" width=100%></center>

# %% [markdown]
# #### 盈利状况

# %% [markdown]
# ```python
#     pyalgotrade.stratanalyzer.returns.Returns类
# ```

# %% [markdown]
# - `getReturns()`：计算每个k线(bar)的收益率

# %% [markdown]
# - `getCumulativeReturns()`：计算每个k线(bar)的累积收益率

# %% [markdown]
# #### 风险大小

# %% [markdown]
# ```python
#     pyalgotrade.stratanalyzer.drawdown.DrawDown类
# ```

# %% [markdown]
# - `getMaxDrawDown()`：获得**最大回撤**

# %% [markdown]
# - `getLongestDrawDownDuration()`：获得**持续时间最长**的回撤所经历的时间，两个高点之间时间距离最长

# %% [markdown]
# <center><img src="./img/performance/drawdownDuration.png" width=100%></center>

# %% [markdown]
# #### 盈利风险综合

# %% [markdown]
# ```python
#     pyalgotrade.stratanalyzer.sharpe.SharpeRatio类
# ```

# %% [markdown]
# - `getSharpeRatio(riskFreeRate)`：获得年化的Sharpe Ratio
#     - `riskFreeRate`：无风险收益率，例如0.03

# %% [markdown]
# #### 逐笔交易统计

# %% [markdown]
# ```python
#     pyalgotrade.stratanalyzer.trades.Trades类
# ```

# %% [markdown]
# - `getCount()`：获得总交易次数

# %% [markdown]
# - `getProfitableCount()`：获得盈利交易的次数

# %% [markdown]
# - `getUnprofitableCount()`：获得亏损交易的次数

# %% [markdown]
# - `getEvenCount()`：获得既不盈利也不亏损的交易次数

# %% [markdown]
# - `getAll()`：获得每笔交易的PnL，是一个`numpy.array`

# %% [markdown]
# - `getAllReturns()`：获得每笔交易的收益率，是一个`numpy.array`

# %% [markdown]
# #### 加载绩效评估

# %% [markdown]
# ```python
#     Strategy.attachAnalyzer(strategyAnalyzer)
# ```
# - `strategyAnalyzer`：各个绩效评估类的对象

# %% [markdown]
# - 例如：
# ```python
#     from pyalgotrade.stratanalyzer import returns, drawdown, sharpe, trades
#     retAnalyzer = returns.Returns()               # 建立收益率对象
#     myStrategy.attachAnalyzer(retAnalyzer)        # 加载收益率对象到策略中
#
#     drawDownAnalyzer = drawDown.DrawDown()        # 建立回撤对象
#     myStrategy.attachAnalyzer(drawDownAnalyzer)   # 加载回撤对象到策略中
#
#     sharpeAnalyzer = sharpe.SharpeRatio()         # 建立Sharpe Ratio对象
#     myStrategy.attachAnalyzer(sharpeAnalyzer)     # 加载Sharpe Ratio对象到策略中
#
#     tradeAnalyzer = trades.Trades()               # 建立逐笔交易统计对象
#     myStrategy.attachAnalyzer(tradeAnalyzer)      # 加载逐笔交易统计对象到策略中
#
#     myStrategy.run()                      # 策略运行
# ```

# %% [markdown]
# - 各个绩效评估模块的加载的位置**一定放在策略运行`run()`之前**

# %% [markdown]
# #### 显示绩效评估结果

# %% [markdown]
# ##### 整体绩效

# %% [markdown]
# ```python
#     myStrategy.info(f'最终权益: {myStrategy.getResult():.2f}')
#     print(f'累计回报率: {retAnalyzer.getCumulativeReturns()[-1] * 100:.2f}%')
#     print(f'夏普比率: {sharpeAnalyzer.getSharpeRatio(0.05):.2f}%')
#     print(f'最大回撤率: {drawDownAnalyzer.getMaxDrawDown() * 100:.2f}%')
#     print(f'最长回撤时间: {drawDownAnalyzer.getLongestDrawDownDuration()}')
# ```

# %% [markdown]
# ##### 逐笔绩效统计

# %% [markdown]
# ```python
#     totalTradeNums = tradeAnalyzer.getCount()
#     print(f'总交易次数: {totalTradeNums}')
#     if totalTradeNums > 0:
#         print(f'交易胜率：{tradeAnalyzer.getProfitableCount()/totalTradeNums*100:.2f}%')
#
#         profits = tradeAnalyzer.getAll()
#         print(f'利润, 均值 {profits.mean():.2f}, 标准差{profits.std():.2f}, 最大值{profits.max():2f}, 最小值{profits.min():.2f}')
#
#         returns = tradesAnalyzer.getAllReturns()
#         print(f'收益率, 均值 {returns.mean()*100:.2f}%, 标准差{returns.std()*100:.2f}%, 最大值{returns.max()*100:.2f}%, 最小值{returns.min()*100:.2f}%')
# ```

# %% [markdown]
# #### 绘图

# %% [markdown]
# ```python
#     pyalgotrade.plotter.StrategyPlotter(strat)类
# ```
# - `strat`：建立的`Strategy`的对象

# %% [markdown]
# <center><img src="./img/performance/pyalgotradePlot.png" width=100%></center>

# %% [markdown]
# - 方法
#     - `plot()`：绘制策略运行图，**必须在策略运行之后**调用

# %% [markdown]
# - 方法
#     - `savePlot(fileName, dpi=None, format='png')`：保存绘制的策略图
#         - `fileName`：保存图片的完整路径
#         - `dpi`：每英寸点数（dots per inch）
#         - `format`：图片格式

# %% [markdown]
# ##### 调用绘图

# %% [markdown]
# ```python
#     from pyalgotrade import plotter
#     # 建立绘制策略图类的对象
#     myplt = plotter.StrategyPlotter(myStrategy)
#     # 运行策略
#     myStrategy.run()
#     # 绘图
#     myplot.plot()
# ```

# %% [markdown]
# #### 完整策略运行

# %% [markdown]
# ##### 导入需要的包

# %%
from pyalgotrade import strategy
from pyalgotrade.technical import ma
from pyalgotrade.barfeed import yahoofeed
from pyalgotrade.stratanalyzer import returns, drawdown, sharpe, trades
from pyalgotrade import plotter

# %% [markdown]
# ##### 建立策略

# %%
class MyStrategy(strategy.BacktestingStrategy):
    def __init__(self, feed, instrument, smaPeriod):
        super(MyStrategy, self).__init__(feed, 50000)
        self.__position = None
        self.__instrument = instrument
        self.__sma = ma.SMA(feed[instrument].getPriceDataSeries(), smaPeriod)

    def onEnterOk(self, position):
        execInfo = position.getEntryOrder().getExecutionInfo()
        self.info(f'建多仓，价格为{execInfo.getPrice():.2f}，数量为{execInfo.getQuantity()}')

    def onExitOk(self, position):
        execInfo = position.getExitOrder().getExecutionInfo()
        self.info(f'平多仓，价格为{execInfo.getPrice():.2f}，数量为{execInfo.getQuantity()}')
        self.__position = None
        
    def onFinish(self, bars):
        self.warning('回测完毕！')

    def onBars(self, bars):
        if self.__sma[-1] is None:
            return

        bar = bars[self.__instrument]
        if self.__position is None:
            if bar.getPrice() > self.__sma[-1]:
                self.__position = self.enterLong(self.__instrument, 5)
        elif bar.getPrice() < self.__sma[-1] and not self.__position.exitActive():
            self.__position.exitMarket()

# %% [markdown]
# ##### 加载数据源

# %%
myfeed = yahoofeed.Feed()
myfeed.addBarsFromCSV('maotai','./data/performance/maotai.csv')

# %% [markdown]
# ##### 建立策略对象

# %%
myStrategy = MyStrategy(myfeed,'maotai',30)

# %% [markdown]
# ##### 建立评估指标和绘图

# %%
retAnalyzer = returns.Returns()
myStrategy.attachAnalyzer(retAnalyzer)

drawDownAnalyzer = drawdown.DrawDown()
myStrategy.attachAnalyzer(drawDownAnalyzer)

sharpeAnalyzer = sharpe.SharpeRatio()
myStrategy.attachAnalyzer(sharpeAnalyzer)

tradeAnalyzer = trades.Trades()
myStrategy.attachAnalyzer(tradeAnalyzer)

myplt = plotter.StrategyPlotter(myStrategy)

# %% [markdown]
# ##### 运行策略

# %%
myStrategy.run()
# Out:
# 2010-02-22 00:00:00 strategy [INFO] 建多仓，价格为129.98，数量为5
# 2010-02-24 00:00:00 strategy [INFO] 平多仓，价格为125.29，数量为5
# 2010-02-25 00:00:00 strategy [INFO] 建多仓，价格为125.39，数量为5
# 2010-03-01 00:00:00 strategy [INFO] 平多仓，价格为125.06，数量为5
# 2010-06-04 00:00:00 strategy [INFO] 建多仓，价格为101.38，数量为5
# 2010-06-21 00:00:00 strategy [INFO] 平多仓，价格为99.47，数量为5
# 2010-06-22 00:00:00 strategy [INFO] 建多仓，价格为100.12，数量为5
# 2010-06-23 00:00:00 strategy [INFO] 平多仓，价格为99.17，数量为5
# 2010-07-19 00:00:00 strategy [INFO] 建多仓，价格为99.96，数量为5
# 2010-10-14 00:00:00 strategy [INFO] 平多仓，价格为119.38，数量为5
# 2010-10-21 00:00:00 strategy [INFO] 建多仓，价格为125.92，数量为5
# 2010-11-01 00:00:00 strategy [INFO] 平多仓，价格为122.61，数量为5
# 2010-11-10 00:00:00 strategy [INFO] 建多仓，价格为125.17，数量为5
# 2010-11-18 00:00:00 strategy [INFO] 平多仓，价格为125.13，数量为5
# 2010-11-19 00:00:00 strategy [INFO] 建多仓，价格为128.55，数量为5
# 2010-12-23 00:00:00 strategy [INFO] 平多仓，价格为143.39，数量为5
# 2011-02-09 00:00:00 strategy [INFO] 建多仓，价格为135.23，数量为5
# 2011-02-10 00:00:00 strategy [INFO] 平多仓，价格为133.25，数量为5
# 2011-02-11 00:00:00 strategy [INFO] 建多仓，价格为138.80，数量为5
# 2011-03-01 00:00:00 strategy [INFO] 平多仓，价格为134.27，数量为5
# 2011-03-11 00:00:00 strategy [INFO] 建多仓，价格为136.44，数量为5
# 2011-03-16 00:00:00 strategy [INFO] 平多仓，价格为134.94，数量为5
# 2011-03-17 00:00:00 strategy [INFO] 建多仓，价格为135.91，数量为5
# 2011-03-29 00:00:00 strategy [INFO] 平多仓，价格为135.99，数量为5
# 2011-04-26 00:00:00 strategy [INFO] 建多仓，价格为137.49，数量为5
# 2011-04-29 00:00:00 strategy [INFO] 平多仓，价格为134.04，数量为5
# 2011-05-03 00:00:00 strategy [INFO] 建多仓，价格为137.49，数量为5
# 2011-09-06 00:00:00 strategy [INFO] 平多仓，价格为170.25，数量为5
# 2011-10-25 00:00:00 strategy [INFO] 建多仓，价格为164.63，数量为5
# 2011-12-07 00:00:00 strategy [INFO] 平多仓，价格为168.35，数量为5
# 2012-02-10 00:00:00 strategy [INFO] 建多仓，价格为156.64，数量为5
# 2012-04-05 00:00:00 strategy [INFO] 平多仓，价格为162.07，数量为5
# 2012-04-06 00:00:00 strategy [INFO] 建多仓，价格为169.93，数量为5
# 2012-05-21 00:00:00 strategy [INFO] 平多仓，价格为179.82，数量为5
# 2012-05-22 00:00:00 strategy [INFO] 建多仓，价格为185.96，数量为5
# 2012-05-25 00:00:00 strategy [INFO] 平多仓，价格为182.02，数量为5
# 2012-05-30 00:00:00 strategy [INFO] 建多仓，价格为188.02，数量为5
# 2012-07-19 00:00:00 strategy [INFO] 平多仓，价格为201.65，数量为5
# 2012-07-25 00:00:00 strategy [INFO] 建多仓，价格为206.61，数量为5
# 2012-08-01 00:00:00 strategy [INFO] 平多仓，价格为203.46，数量为5
# 2012-08-08 00:00:00 strategy [INFO] 建多仓，价格为208.65，数量为5
# 2012-08-13 00:00:00 strategy [INFO] 平多仓，价格为205.35，数量为5
# 2012-09-10 00:00:00 strategy [INFO] 建多仓，价格为199.76，数量为5
# 2012-09-20 00:00:00 strategy [INFO] 平多仓，价格为190.83，数量为5
# 2012-09-26 00:00:00 strategy [INFO] 建多仓，价格为196.69，数量为5
# 2012-10-29 00:00:00 strategy [INFO] 平多仓，价格为199.66，数量为5
# 2012-10-31 00:00:00 strategy [INFO] 建多仓，价格为202.08，数量为5
# 2012-11-06 00:00:00 strategy [INFO] 平多仓，价格为200.34，数量为5
# 2012-12-20 00:00:00 strategy [INFO] 建多仓，价格为180.58，数量为5
# 2012-12-25 00:00:00 strategy [INFO] 平多仓，价格为167.69，数量为5
# 2012-12-31 00:00:00 strategy [INFO] 建多仓，价格为176.29，数量为5
# 2013-01-04 00:00:00 strategy [INFO] 平多仓，价格为175.21，数量为5
# 2013-01-09 00:00:00 strategy [INFO] 建多仓，价格为174.79，数量为5
# 2013-01-17 00:00:00 strategy [INFO] 平多仓，价格为169.41，数量为5
# 2013-03-08 00:00:00 strategy [INFO] 建多仓，价格为153.73，数量为5
# 2013-03-15 00:00:00 strategy [INFO] 平多仓，价格为146.71，数量为5
# 2013-04-15 00:00:00 strategy [INFO] 建多仓，价格为142.37，数量为5
# 2013-06-17 00:00:00 strategy [INFO] 平多仓，价格为160.55，数量为5
# 2013-07-03 00:00:00 strategy [INFO] 建多仓，价格为164.38，数量为5
# 2013-07-09 00:00:00 strategy [INFO] 平多仓，价格为162.23，数量为5
# 2013-07-12 00:00:00 strategy [INFO] 建多仓，价格为161.25，数量为5
# 2013-07-15 00:00:00 strategy [INFO] 平多仓，价格为156.51，数量为5
# 2013-10-22 00:00:00 strategy [INFO] 建多仓，价格为119.67，数量为5
# 2013-10-23 00:00:00 strategy [INFO] 平多仓，价格为118.40，数量为5
# 2013-10-24 00:00:00 strategy [INFO] 建多仓，价格为118.43，数量为5
# 2013-10-28 00:00:00 strategy [INFO] 平多仓，价格为112.21，数量为5
# 2013-11-07 00:00:00 strategy [INFO] 建多仓，价格为115.17，数量为5
# 2013-11-11 00:00:00 strategy [INFO] 平多仓，价格为114.05，数量为5
# 2013-11-12 00:00:00 strategy [INFO] 建多仓，价格为115.22，数量为5
# 2013-11-22 00:00:00 strategy [INFO] 平多仓，价格为114.60，数量为5
# 2013-11-26 00:00:00 strategy [INFO] 建多仓，价格为116.52，数量为5
# 2013-11-27 00:00:00 strategy [INFO] 平多仓，价格为115.69，数量为5
# 2013-11-29 00:00:00 strategy [INFO] 建多仓，价格为116.53，数量为5
# 2013-12-03 00:00:00 strategy [INFO] 平多仓，价格为112.85，数量为5
# 2014-01-21 00:00:00 strategy [INFO] 建多仓，价格为104.13，数量为5
# 2014-03-31 00:00:00 strategy [INFO] 平多仓，价格为125.63，数量为5
# 2014-04-02 00:00:00 strategy [INFO] 建多仓，价格为134.50，数量为5
# 2014-04-28 00:00:00 strategy [INFO] 平多仓，价格为133.95，数量为5
# 2014-06-24 00:00:00 strategy [INFO] 建多仓，价格为129.44，数量为5
# 2014-08-20 00:00:00 strategy [INFO] 平多仓，价格为144.31，数量为5
# 2014-08-21 00:00:00 strategy [INFO] 建多仓，价格为147.27，数量为5
# 2014-08-22 00:00:00 strategy [INFO] 平多仓，价格为145.46，数量为5
# 2014-09-03 00:00:00 strategy [INFO] 建多仓，价格为147.80，数量为5
# 2014-09-16 00:00:00 strategy [INFO] 平多仓，价格为145.91，数量为5
# 2014-09-26 00:00:00 strategy [INFO] 建多仓，价格为146.82，数量为5
# 2014-10-10 00:00:00 strategy [INFO] 平多仓，价格为144.56，数量为5
# 2014-11-17 00:00:00 strategy [INFO] 建多仓，价格为152.73，数量为5
# 2014-11-19 00:00:00 strategy [INFO] 平多仓，价格为141.43，数量为5
# 2014-11-27 00:00:00 strategy [INFO] 建多仓，价格为140.91，数量为5
# 2015-01-20 00:00:00 strategy [INFO] 平多仓，价格为160.02，数量为5
# 2015-02-10 00:00:00 strategy [INFO] 建多仓，价格为168.00，数量为5
# 2015-02-11 00:00:00 strategy [INFO] 平多仓，价格为165.82，数量为5
# 2015-02-13 00:00:00 strategy [INFO] 建多仓，价格为167.37，数量为5
# 2015-02-16 00:00:00 strategy [INFO] 平多仓，价格为165.95，数量为5
# 2015-02-17 00:00:00 strategy [INFO] 建多仓，价格为166.86，数量为5
# 2015-06-08 00:00:00 strategy [INFO] 平多仓，价格为228.65，数量为5
# 2015-06-09 00:00:00 strategy [INFO] 建多仓，价格为240.91，数量为5
# 2015-06-17 00:00:00 strategy [INFO] 平多仓，价格为230.87，数量为5
# 2015-06-25 00:00:00 strategy [INFO] 建多仓，价格为237.73，数量为5
# 2015-06-26 00:00:00 strategy [INFO] 平多仓，价格为227.29，数量为5
# 2015-07-10 00:00:00 strategy [INFO] 建多仓，价格为233.64，数量为5
# 2015-07-15 00:00:00 strategy [INFO] 平多仓，价格为225.00，数量为5
# 2015-09-15 00:00:00 strategy [INFO] 建多仓，价格为198.01，数量为5
# 2015-09-24 00:00:00 strategy [INFO] 平多仓，价格为195.80，数量为5
# 2015-10-09 00:00:00 strategy [INFO] 建多仓，价格为198.78，数量为5
# 2015-11-25 00:00:00 strategy [INFO] 平多仓，价格为211.70，数量为5
# 2015-11-26 00:00:00 strategy [INFO] 建多仓，价格为213.49，数量为5
# 2015-11-30 00:00:00 strategy [INFO] 平多仓，价格为208.04，数量为5
# 2015-12-01 00:00:00 strategy [INFO] 建多仓，价格为213.00，数量为5
# 2015-12-02 00:00:00 strategy [INFO] 平多仓，价格为214.48，数量为5
# 2015-12-03 00:00:00 strategy [INFO] 建多仓，价格为219.00，数量为5
# 2015-12-08 00:00:00 strategy [INFO] 平多仓，价格为214.55，数量为5
# 2015-12-18 00:00:00 strategy [INFO] 建多仓，价格为215.50，数量为5
# 2016-01-05 00:00:00 strategy [INFO] 平多仓，价格为210.00，数量为5
# 2016-02-22 00:00:00 strategy [INFO] 建多仓，价格为206.00，数量为5
# 2016-04-21 00:00:00 strategy [INFO] 平多仓，价格为240.50，数量为5
# 2016-04-25 00:00:00 strategy [INFO] 建多仓，价格为247.12，数量为5
# 2016-05-19 00:00:00 strategy [INFO] 平多仓，价格为245.16，数量为5
# 2016-05-23 00:00:00 strategy [INFO] 建多仓，价格为249.72，数量为5
# 2016-08-05 00:00:00 strategy [INFO] 平多仓，价格为306.49，数量为5
# 2016-08-10 00:00:00 strategy [INFO] 建多仓，价格为315.05，数量为5
# 2016-08-17 00:00:00 strategy [INFO] 平多仓，价格为309.60，数量为5
# 2016-09-01 00:00:00 strategy [INFO] 建多仓，价格为309.70，数量为5
# 2016-09-02 00:00:00 strategy [INFO] 平多仓，价格为308.00，数量为5
# 2016-09-07 00:00:00 strategy [INFO] 建多仓，价格为309.68，数量为5
# 2016-09-08 00:00:00 strategy [INFO] 平多仓，价格为305.21，数量为5
# 2016-10-11 00:00:00 strategy [INFO] 建多仓，价格为304.00，数量为5
# 2016-11-18 00:00:00 strategy [INFO] 平多仓，价格为311.16，数量为5
# 2016-11-24 00:00:00 strategy [INFO] 建多仓，价格为313.20，数量为5
# 2016-12-26 00:00:00 strategy [INFO] 平多仓，价格为319.03，数量为5
# 2016-12-27 00:00:00 strategy [INFO] 建多仓，价格为324.51，数量为5
# 2017-07-04 00:00:00 strategy [INFO] 平多仓，价格为458.96，数量为5
# 2017-07-21 00:00:00 strategy [INFO] 建多仓，价格为466.96，数量为5
# 2017-09-07 00:00:00 strategy [INFO] 平多仓，价格为485.31，数量为5
# 2017-09-14 00:00:00 strategy [INFO] 建多仓，价格为492.99，数量为5
# 2017-11-27 00:00:00 strategy [INFO] 平多仓，价格为634.00，数量为5
# 2017-11-29 00:00:00 strategy [INFO] 建多仓，价格为649.94，数量为5
# 2017-11-30 00:00:00 strategy [INFO] 平多仓，价格为635.51，数量为5
# 2017-12-12 00:00:00 strategy [INFO] 建多仓，价格为658.70，数量为5
# 2018-02-05 00:00:00 strategy [INFO] 平多仓，价格为727.22，数量为5
# 2018-03-02 00:00:00 strategy [INFO] 建多仓，价格为738.00，数量为5
# 2018-03-05 00:00:00 strategy [INFO] 平多仓，价格为738.18，数量为5
# 2018-03-16 00:00:00 strategy [INFO] 建多仓，价格为747.60，数量为5
# 2018-03-26 00:00:00 strategy [INFO] 平多仓，价格为708.00，数量为5
# 2018-05-08 00:00:00 strategy [INFO] 建多仓，价格为698.03，数量为5
# 2018-06-20 00:00:00 strategy [INFO] 平多仓，价格为741.00，数量为5
# 2018-06-21 00:00:00 strategy [INFO] 建多仓，价格为765.22，数量为5
# 2018-06-27 00:00:00 strategy [INFO] 平多仓，价格为752.00，数量为5
# 2018-07-17 00:00:00 strategy [INFO] 建多仓，价格为757.00，数量为5
# 2018-07-18 00:00:00 strategy [INFO] 平多仓，价格为742.43，数量为5
# 2018-07-25 00:00:00 strategy [INFO] 建多仓，价格为746.95，数量为5
# 2018-07-27 00:00:00 strategy [INFO] 平多仓，价格为736.00，数量为5
# 2018-07-30 00:00:00 strategy [INFO] 建多仓，价格为738.90，数量为5
# 2018-07-31 00:00:00 strategy [INFO] 平多仓，价格为720.30，数量为5
# 2018-09-19 00:00:00 strategy [INFO] 建多仓，价格为666.58，数量为5
# 2018-10-11 00:00:00 strategy [INFO] 平多仓，价格为635.01，数量为5
# 2018-10-22 00:00:00 strategy [INFO] 建多仓，价格为675.00，数量为5
# 2018-10-24 00:00:00 strategy [INFO] 平多仓，价格为628.11，数量为5
# 2018-12-04 00:00:00 strategy [INFO] 建多仓，价格为602.99，数量为5
# 2018-12-24 00:00:00 strategy [INFO] 平多仓，价格为563.50，数量为5
# 2019-01-02 00:00:00 strategy [INFO] 建多仓，价格为609.98，数量为5
# 2019-05-09 00:00:00 strategy [INFO] 平多仓，价格为875.00，数量为5
# 2019-05-13 00:00:00 strategy [INFO] 建多仓，价格为898.86，数量为5
# 2019-05-14 00:00:00 strategy [INFO] 平多仓，价格为885.00，数量为5
# 2019-05-16 00:00:00 strategy [INFO] 建多仓，价格为919.00，数量为5
# 2019-05-20 00:00:00 strategy [INFO] 平多仓，价格为900.00，数量为5
# 2019-06-12 00:00:00 strategy [INFO] 建多仓，价格为906.22，数量为5
# 2019-07-19 00:00:00 strategy [INFO] 平多仓，价格为955.00，数量为5
# 2019-07-30 00:00:00 strategy [INFO] 建多仓，价格为976.50，数量为5
# 2019-08-01 00:00:00 strategy [INFO] 平多仓，价格为976.51，数量为5
# 2019-08-13 00:00:00 strategy [INFO] 建多仓，价格为1016.16，数量为5
# 2019-10-25 00:00:00 strategy [INFO] 平多仓，价格为1153.30，数量为5
# 2019-10-28 00:00:00 strategy [INFO] 建多仓，价格为1166.01，数量为5
# 2019-11-25 00:00:00 strategy [INFO] 平多仓，价格为1188.05，数量为5
# 2019-12-31 00:00:00 strategy [INFO] 建多仓，价格为1183.00，数量为5
# 2020-01-03 00:00:00 strategy [INFO] 平多仓，价格为1117.00，数量为5
# 2020-02-20 00:00:00 strategy [INFO] 建多仓，价格为1096.70，数量为5
# 2020-02-26 00:00:00 strategy [INFO] 平多仓，价格为1062.00，数量为5
# 2020-02-28 00:00:00 strategy [INFO] 建多仓，价格为1070.30，数量为5
# 2020-03-02 00:00:00 strategy [INFO] 平多仓，价格为1050.11，数量为5
# 2020-03-03 00:00:00 strategy [INFO] 建多仓，价格为1098.00，数量为5
# 2020-03-17 00:00:00 strategy [INFO] 平多仓，价格为1055.00，数量为5
# 2020-04-01 00:00:00 strategy [INFO] 建多仓，价格为1117.00，数量为5
# 2020-08-10 00:00:00 strategy [INFO] 平多仓，价格为1627.97，数量为5
# 2020-08-18 00:00:00 strategy [INFO] 建多仓，价格为1697.38，数量为5
# 2020-08-21 00:00:00 strategy [INFO] 平多仓，价格为1673.00，数量为5
# 2020-08-24 00:00:00 strategy [INFO] 建多仓，价格为1699.94，数量为5
# 2020-09-10 00:00:00 strategy [INFO] 平多仓，价格为1703.74，数量为5
# 2020-09-11 00:00:00 strategy [INFO] 建多仓，价格为1688.00，数量为5
# 2020-09-18 00:00:00 strategy [INFO] 平多仓，价格为1665.00，数量为5
# 2020-10-13 00:00:00 strategy [INFO] 建多仓，价格为1750.62，数量为5
# 2020-10-19 00:00:00 strategy [INFO] 平多仓，价格为1725.00，数量为5
# 2020-10-21 00:00:00 strategy [INFO] 建多仓，价格为1734.10，数量为5
# 2020-10-27 00:00:00 strategy [INFO] 平多仓，价格为1643.00，数量为5
# 2020-11-04 00:00:00 strategy [INFO] 建多仓，价格为1700.00，数量为5
# 2020-11-19 00:00:00 strategy [INFO] 平多仓，价格为1684.50，数量为5
# 2020-11-20 00:00:00 strategy [INFO] 建多仓，价格为1720.00，数量为5
# 2020-11-23 19:27:36,911 strategy [WARNING] 回测完毕！

# %% [markdown]
# ##### 显示结果

# %%
myplt.plot()
totalTradeNums = tradeAnalyzer.getCount()
print(f'最终权益: {myStrategy.getResult():.2f}')
print(f'累计回报率: {retAnalyzer.getCumulativeReturns()[-1] * 100:.2f}%')
print(f'夏普比率: {sharpeAnalyzer.getSharpeRatio(0.05):.2f}')
print(f'最大回撤率: {drawDownAnalyzer.getMaxDrawDown() * 100:.2f}%')
print(f'最长回撤时间: {drawDownAnalyzer.getLongestDrawDownDuration()}')
print(f'总交易次数: {totalTradeNums}')
if totalTradeNums > 0:
    print(f'交易胜率：{tradeAnalyzer.getProfitableCount()/totalTradeNums*100:.2f}%')

    profits = tradeAnalyzer.getAll()
    print(f'PnL, 均值 {profits.mean():.2f}, 标准差{profits.std():.2f}, 最大值{profits.max():2f}, 最小值{profits.min():.2f}')

    returns = tradeAnalyzer.getAllReturns()
    print(f'收益率, 均值 {returns.mean()*100:.2f}%, 标准差{returns.std()*100:.2f}%, 最大值{returns.max()*100:.2f}%, 最小值{returns.min()*100:.2f}%')
# Out:
# 最终权益: 54859.34
# 累计回报率: 9.72%
# 夏普比率: -3.01
# 最大回撤率: 2.92%
# 最长回撤时间: 901 days, 0:00:00
# 总交易次数: 98
# 交易胜率：33.67%
# PnL, 均值 49.59, 标准差330.14, 最大值2554.849854, 最小值-455.50
# 收益率, 均值 2.67%, 标准差10.65%, 最大值45.74%, 最小值-7.40%

# %% [markdown]
# ## 策略例子

# %% [markdown]
# ### 基于布林线的均值回归策略

# %% [markdown]
# - 当收盘价低于布林线下界的时候，**平空仓**，**建多仓**
# - 当收盘价超过布林线上界的时候，**平多仓**，**建空仓**

# %% [markdown]
# #### 导入需要的包

# %%
from pyalgotrade import strategy, plotter
from pyalgotrade.technical import bollinger
from pyalgotrade.stratanalyzer import returns, sharpe, trades, drawdown
from pyalgotrade.barfeed import yahoofeed

# %% [markdown]
# #### 建立策略

# %%
class myBBands(strategy.BacktestingStrategy):
    
    def __init__(self, feed, instrument, bBandsPeriod, numDev, initEquity):
        super(myBBands, self).__init__(feed, initEquity)
        self.__instrument = instrument
        self.__bbands = bollinger.BollingerBands(feed[instrument].getCloseDataSeries(), bBandsPeriod, numDev)
        self.__longPosition = None
        self.__shortPosition = None

    def getBollingerBands(self):
        return self.__bbands
    
    def onExitOk(self, position):
        order = position.getExitOrder()
        execInfo = order.getExecutionInfo()
        self.info(f'{self.action_type(order)}，价格为{execInfo.getPrice():.2f}')
        if self.__shortPosition == position:
            self.__shortPosition = None
        elif self.__longPosition == position:
            self.__longPosition = None
        
    def onEnterOk(self, position):
        order = position.getEntryOrder()
        execInfo = order.getExecutionInfo()
        self.info(f'{self.action_type(order)}，价格为{execInfo.getPrice():.2f}')
        
    def action_type(self, order):
        actionType = order.getAction()
        typeMeaning = ''
        if actionType == 1:
            typeMeaning = '建多仓'
        elif actionType == 2:
            typeMeaning = '平空仓'
        elif actionType == 3:
            typeMeaning = '平多仓'
        elif actionType == 4:
            typeMeaning = '建空仓'
        return typeMeaning
            

    def onBars(self, bars):
        lower = self.__bbands.getLowerBand()[-1]
        mid = self.__bbands.getMiddleBand()[-1]
        upper = self.__bbands.getUpperBand()[-1]
        if lower is None:
            return

        bar = bars[self.__instrument]
        
        if bar.getClose() < lower:
            if self.__longPosition is None:
                # 没有多仓
                self.__longPosition = self.enterLong(self.__instrument, 5)
        elif bar.getClose() > upper:
            if self.__shortPosition is None:
                # 没有空仓
                self.__shortPosition = self.enterShort(self.__instrument, 5)
        elif bar.getClose() < mid:
            if self.__longPosition is not None and self.__longPosition.exitActive() is False:
                # 有多仓，并且没有平多仓的挂单
                self.__longPosition.exitMarket()
        elif bar.getClose() > mid:
            if self.__shortPosition is not None and self.__shortPosition.exitActive() is False:
            # 有空仓，并且没有平空仓的挂单
                self.__shortPosition.exitMarket()

# %% [markdown]
# #### 设定评估指标

# %%
def strategy_evaluation(inputStrategy):
    retAnalyzer = returns.Returns()
    sharpeAnalyzer = sharpe.SharpeRatio()
    ddAnalyzer = drawdown.DrawDown()
    tradesAnalyzer = trades.Trades()
    
    inputStrategy.attachAnalyzer(retAnalyzer)
    inputStrategy.attachAnalyzer(sharpeAnalyzer)
    inputStrategy.attachAnalyzer(ddAnalyzer)
    inputStrategy.attachAnalyzer(tradesAnalyzer)
    
    return retAnalyzer, sharpeAnalyzer, ddAnalyzer, tradesAnalyzer

# %% [markdown]
# #### 绘图

# %%
def strategy_plot(inputStrategy, instrument):
    strPlt = plotter.StrategyPlotter(inputStrategy)
    return strPlt

# %% [markdown]
# #### 读入数据

# %%
def read_data(instrument, datpath):
    strFeed = yahoofeed.Feed()
    strFeed.addBarsFromCSV(instrument, datpath)
    return strFeed

# %% [markdown]
# #### 主函数

# %%
def main():
    instrument = 'maotai'
    bBandsPeriod = 20
    numDev = 3
    feed = read_data(instrument, f'./data/performance/{instrument}.csv')
    
    strat = myBBands(feed, instrument, bBandsPeriod, numDev, 50000)
    
    retEval, sharpeEval, ddEval, tradesEval = strategy_evaluation(strat)
    
    stratPlt = strategy_plot(strat, instrument)
    
    strat.run()
    
    print(f'最终权益为：{strat.getResult()}')
    print(f'最终累积收益率为：{retEval.getCumulativeReturns()[-1]*100:.2f}%')
    print(f'Sharpe Ratio为：{sharpeEval.getSharpeRatio(0.03):.2f}')
    print(f'最大回撤为：{ddEval.getMaxDrawDown()*100:.2f}%')
    print(f'最长回撤时间为：{ddEval.getLongestDrawDownDuration()}')
    print(f'总交易次数为：{tradesEval.getCount()}')
    if tradesEval.getCount() > 0:
        print(f'胜率为：{tradesEval.getProfitableCount()/tradesEval.getCount()*100:.2f}%')
    
    stratPlt.savePlot('./img/performance/bbandsStrategy.png',dpi=300)

# %%
main()
# Out:
# 2010-11-11 00:00:00 strategy [INFO] 建空仓，价格为136.73
# 2010-11-12 00:00:00 strategy [INFO] 平空仓，价格为131.89
# 2012-07-04 00:00:00 strategy [INFO] 建空仓，价格为212.40
# 2012-07-05 00:00:00 strategy [INFO] 平空仓，价格为207.93
# 2013-09-03 00:00:00 strategy [INFO] 建多仓，价格为124.79
# 2013-09-04 00:00:00 strategy [INFO] 平多仓，价格为125.62
# 2014-06-25 00:00:00 strategy [INFO] 建空仓，价格为132.12
# 2014-06-26 00:00:00 strategy [INFO] 平空仓，价格为129.30
# 2014-11-06 00:00:00 strategy [INFO] 建多仓，价格为132.86
# 2014-11-07 00:00:00 strategy [INFO] 平多仓，价格为133.79
# 2014-12-05 00:00:00 strategy [INFO] 建空仓，价格为161.81
# 2014-12-08 00:00:00 strategy [INFO] 平空仓，价格为153.49
# 2015-04-17 00:00:00 strategy [INFO] 建空仓，价格为217.18
# 2015-04-21 00:00:00 strategy [INFO] 平空仓，价格为218.18
# 2015-04-22 00:00:00 strategy [INFO] 建空仓，价格为244.36
# 2015-04-23 00:00:00 strategy [INFO] 平空仓，价格为240.00
# 2015-05-25 00:00:00 strategy [INFO] 建空仓，价格为245.46
# 2015-05-27 00:00:00 strategy [INFO] 平空仓，价格为259.56
# 2015-08-24 00:00:00 strategy [INFO] 建多仓，价格为181.00
# 2015-08-26 00:00:00 strategy [INFO] 平多仓，价格为176.76
# 2015-12-22 00:00:00 strategy [INFO] 建空仓，价格为226.80
# 2015-12-23 00:00:00 strategy [INFO] 平空仓，价格为225.45
# 2016-02-24 00:00:00 strategy [INFO] 建空仓，价格为212.20
# 2016-02-26 00:00:00 strategy [INFO] 平空仓，价格为213.10
# 2016-06-06 00:00:00 strategy [INFO] 建空仓，价格为282.00
# 2016-06-07 00:00:00 strategy [INFO] 平空仓，价格为276.50
# 2016-07-07 00:00:00 strategy [INFO] 建空仓，价格为315.80
# 2016-07-08 00:00:00 strategy [INFO] 平空仓，价格为313.53
# 2017-01-05 00:00:00 strategy [INFO] 建空仓，价格为350.00
# 2017-01-06 00:00:00 strategy [INFO] 平空仓，价格为346.64
# 2018-10-31 00:00:00 strategy [INFO] 建多仓，价格为527.00
# 2018-11-01 00:00:00 strategy [INFO] 平多仓，价格为555.00
# 2018-12-04 00:00:00 strategy [INFO] 建空仓，价格为602.99
# 2018-12-05 00:00:00 strategy [INFO] 平空仓，价格为597.50
# 2019-08-13 00:00:00 strategy [INFO] 建空仓，价格为1016.16
# 2019-08-14 00:00:00 strategy [INFO] 平空仓，价格为1030.02
# 2020-01-06 00:00:00 strategy [INFO] 建多仓，价格为1070.86
# 2020-01-07 00:00:00 strategy [INFO] 平多仓，价格为1077.50
# 2020-03-06 00:00:00 strategy [INFO] 建空仓，价格为1163.00
# 2020-03-09 00:00:00 strategy [INFO] 平空仓，价格为1135.00
# 最终权益为：50365.28461456299
# 最终累积收益率为：0.73%
# Sharpe Ratio为：-21.55
# 最大回撤为：0.28%
# 最长回撤时间为：1292 days, 0:00:00
# 总交易次数为：20
# 胜率为：75.00%

# %% [markdown]
# ## 模型优化

# %% [markdown]
# - 模型参数的选择

# %% [markdown]
# ### 最优参数选择

# %% [markdown]
# - 直接优化法
#     - 设定目标函数
#     - 设定参数取值范围**组合**

# %% [markdown]
# #### 参数的搜索空间

# %% [markdown]
# - 例如：基于布林线的均值回归策略

# %% [markdown]
# - 两个参数，布林线上下界时间窗口、中线离上下界的距离（标准差的倍数）

# %%
paraTup = []
for each in range(20,50,5):
    for num in np.linspace(0.5,2.5,5):
        paraTup.append((each,num))
print(paraTup)
# Out:
# [(20, 0.5), (20, 1.0), (20, 1.5), (20, 2.0), (20, 2.5), (25, 0.5), (25, 1.0), (25, 1.5), (25, 2.0), (25, 2.5), (30, 0.5), (30, 1.0), (30, 1.5), (30, 2.0), (30, 2.5), (35, 0.5), (35, 1.0), (35, 1.5), (35, 2.0), (35, 2.5), (40, 0.5), (40, 1.0), (40, 1.5), (40, 2.0), (40, 2.5), (45, 0.5), (45, 1.0), (45, 1.5), (45, 2.0), (45, 2.5)]

# %%
class myBBands(strategy.BacktestingStrategy):
    
    def __init__(self, feed, instrument, bBandsPeriod, numDev, initEquity):
        super(myBBands, self).__init__(feed, initEquity)
        self.__instrument = instrument
        self.__bbands = bollinger.BollingerBands(feed[instrument].getCloseDataSeries(), bBandsPeriod, numDev)
        self.__longPosition = None
        self.__shortPosition = None

    def getBollingerBands(self):
        return self.__bbands
    
    def onExitOk(self, position):
#         order = position.getExitOrder()
#         execInfo = order.getExecutionInfo()
#         self.info(f'{self.action_type(order)}，价格为{execInfo.getPrice():.2f}')
        if self.__shortPosition == position:
            self.__shortPosition = None
        elif self.__longPosition == position:
            self.__longPosition = None
        
#     def onEnterOk(self, position):
#         order = position.getEntryOrder()
#         execInfo = order.getExecutionInfo()
#         self.info(f'{self.action_type(order)}，价格为{execInfo.getPrice():.2f}')
        
    def action_type(self, order):
        actionType = order.getAction()
        typeMeaning = ''
        if actionType == 1:
            typeMeaning = '建多仓'
        elif actionType == 2:
            typeMeaning = '平空仓'
        elif actionType == 3:
            typeMeaning = '平多仓'
        elif actionType == 4:
            typeMeaning = '建空仓'
        return typeMeaning
            

    def onBars(self, bars):
        lower = self.__bbands.getLowerBand()[-1]
        mid = self.__bbands.getMiddleBand()[-1]
        upper = self.__bbands.getUpperBand()[-1]
        if lower is None:
            return

        bar = bars[self.__instrument]
        
        
        if bar.getClose() < lower:
            if self.__longPosition is None:
                # 没有多仓
                self.__longPosition = self.enterLong(self.__instrument, 5)
        elif bar.getClose() > upper:
            if self.__shortPosition is None:
                # 没有空仓
                self.__shortPosition = self.enterShort(self.__instrument, 5)
        elif bar.getClose() < mid:
            if self.__longPosition is not None and self.__longPosition.exitActive() is False:
                # 有多仓，并且没有平多仓的挂单
                self.__longPosition.exitMarket()
        elif bar.getClose() > mid:
            if self.__shortPosition is not None and self.__shortPosition.exitActive() is False:
            # 有空仓，并且没有平空仓的挂单
                self.__shortPosition.exitMarket()

# %%
def main(bBandsPeriod, numDev):
    instrument = 'maotai'
    feed = read_data(instrument, './data/performance/maotai.csv')
    
    strat = myBBands(feed, instrument, bBandsPeriod, numDev, 50000)
    
    retEval, sharpeEval, ddEval, tradesEval = strategy_evaluation(strat)
    
    stratPlt = strategy_plot(strat, instrument)
    
    strat.run()
    
    sharpe = sharpeEval.getSharpeRatio(0.03)
    print(f'Sharpe Ratio为：{sharpe}')
    return sharpe

# %%
resLst = []
for period, num in paraTup:
    resLst.append(main(period,num))
# Out:
# Sharpe Ratio为：-2.326001537738314
# Sharpe Ratio为：-1.9911698643919153
# Sharpe Ratio为：-3.044854656799298
# Sharpe Ratio为：-4.677034655061072
# Sharpe Ratio为：-8.117278360418213
# Sharpe Ratio为：-2.0331273697012726
# Sharpe Ratio为：-2.202462891813057
# Sharpe Ratio为：-2.5667424167166986
# Sharpe Ratio为：-4.36536780353669
# Sharpe Ratio为：-7.101708981111702
# Sharpe Ratio为：-2.076822443409807
# Sharpe Ratio为：-2.3705043316590757
# Sharpe Ratio为：-2.638025967458495
# Sharpe Ratio为：-4.139359062520159
# Sharpe Ratio为：-6.663831744558996
# Sharpe Ratio为：-2.191948855609615
# Sharpe Ratio为：-2.179396583890038
# Sharpe Ratio为：-2.684833641513287
# Sharpe Ratio为：-3.435716246259747
# Sharpe Ratio为：-6.857547948354809
# Sharpe Ratio为：-2.108609822633516
# Sharpe Ratio为：-2.304729936394486
# Sharpe Ratio为：-2.784492813247648
# Sharpe Ratio为：-3.3576052517672017
# Sharpe Ratio为：-5.952260004904498
# Sharpe Ratio为：-2.134750906311166
# Sharpe Ratio为：-2.3128592446476834
# Sharpe Ratio为：-2.7996847509182285
# Sharpe Ratio为：-3.4589719320378127
# Sharpe Ratio为：-5.755701908285277

# %%
# %matplotlib notebook
import matplotlib.tri as mtri
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(1,1,1, projection='3d')
x = [each[0] for each in paraTup]
y = [each[1] for each in paraTup]
triag = mtri.Triangulation(x,y)
surf = ax.plot_trisurf(triag,resLst,cmap="RdBu_r")
ax.set(xlabel='period',ylabel='numDev',zlabel='sharpe ratio')
fig.colorbar(surf,ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# [Text(0.5, 0, 'sharpe ratio'), Text(0.5, 0, 'numDev'), Text(0.5, 0, 'period')]

# %% [markdown]
# #### 选什么样的参数？

# %% [markdown]
# - 一个策略的目标函数值随着参数取值的变化

# %% [markdown]
# <center><img src="./img/performance/plateau.PNG" width=100%></center>

# %% [markdown]
# - 选择B点作为最优参数

# %% [markdown]
# - B点位于参数**高原**(plateau)的中心，参数的可靠性高

# %% [markdown]
# - D点是一个参数**孤岛**，可能是过度拟合导致的
